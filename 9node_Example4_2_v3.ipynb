# %% [markdown]
# # **Step1: Design PBCN system for learning**
#
# First we design the environment variables using the knowledge of PBCN parameters, dynamics and rewarding scheme. For other Markovian process that can be extracted from standard libraries like "gym" this step can be omitted.
#
# Once the system is designed and the dynamics computed, we visualize attractors using "networkx" package, which also helps finding attractors in turn seggregating desired and undesired attractors.

# %%
# Import libraries required for PBCN problem
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.model_selection import KFold
# from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# from sklearn.pipeline import Pipeline
# from sklearn.model_selection import train_test_split
import multiprocessing as mp
import numpy as np
import pandas as pd
import random as rd
import matplotlib.pyplot as plt
import itertools
import pandas as pd
import pylab as plt
import networkx as nx
import numpy as np
import time
import sys

# ---------------------->>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Creating PBCN Parameters <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<----------------------------

ns = 9 # Number of State variables
nc = 2 # Number of Control variables
n = ns + nc # Total variables

# Generate table of all possible binary combinations between states-action pairs
table = list(itertools.product([0, 1], repeat=n))

# function to convert boolean to decimal values
def bool2dec(table_name,n_val,table_len,flag):
  dec_value=np.zeros(table_len)
  for i in range(0,table_len):
    for j in range(0,n_val):
      if flag==0:                           # flag defines if control u is taken into consideration or not
        dec_value[i]=(np.power(2,(n_val-j-1)))*table_name[i][j+nc]+dec_value[i] # for u at the beginning
      else:
        dec_value[i]=(np.power(2,(n_val-j-1)))*table_name[i][j]+dec_value[i] # for u at the beginning
  return dec_value

value=bool2dec(table,ns,len(table),0)
df=pd.DataFrame([table[0:len(table)],value])  # Dataframe comprising of state-action pairs and corresponding decimal values

no_of_perm = 4                              # no of possible permutations in reference to states possessing sub network structure
no_of_vars_with_diff_paths = 2              # no of variables possesing sub networks
if no_of_vars_with_diff_paths==1:
  f = np.zeros([ns+int(no_of_vars_with_diff_paths),df.shape[1]])    # f=[[f11f21f31],[f11f22f31],[f12f21f31]...] all possible dynamical functions
else:
  f = np.zeros([ns+int(no_of_perm/no_of_vars_with_diff_paths),df.shape[1]])     # f=[[f11f21f31],[f11f22f31],[f12f21f31]...] all possible dynamical functions

# Boolean dynamics of the system given by x_{k+1} = f_{x_{k},u_{k}}
for i in range(0,df.shape[1]):
  f[0,i]=(1-df[i][0][8]) and df[i][0][4]
  f[1,i]=df[i][0][2]
  f[2,i]=(1-df[i][0][0])
  f[3,i]=df[i][0][6] and df[i][0][7]
  f[4,i]=(1-df[i][0][0]) and df[i][0][3] and df[i][0][1]
  f[5,i]=df[i][0][6]
  f[6,i]=df[i][0][2]
  f[7,i]=(1-df[i][0][5]) and (1-df[i][0][9])
  f[8,i]=df[i][0][5] or df[i][0][6] or df[i][0][10]
  f[9,i]=(1-df[i][0][0]) and (df[i][0][6] or df[i][0][1])
  f[10,i]=df[i][0][10]

# creating and storing dataframes for individual sub networks
dummy_df=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[4,:],f[6,:],f[7,:],f[8,:],f[9,:]])
df2=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[4,:],f[6,:],f[7,:],f[8,:],f[9,:],bool2dec(dummy_df,ns,df.shape[1],1)])    # subnetwork with combination: sc1 = f11,f21,f31...f51...f91
dummy_df=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[5,:],f[6,:],f[7,:],f[8,:],f[9,:]])
df3=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[5,:],f[6,:],f[7,:],f[8,:],f[9,:],bool2dec(dummy_df,ns,df.shape[1],1)])    # subnetwork with combination: sc1 = f11,f21,f31...f52...f91
dummy_df=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[4,:],f[6,:],f[7,:],f[8,:],f[10,:]])
df4=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[4,:],f[6,:],f[7,:],f[8,:],f[10,:],bool2dec(dummy_df,ns,df.shape[1],1)])   # subnetwork with combination: sc1 = f11,f21,f31...f51...f92
dummy_df=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[5,:],f[6,:],f[7,:],f[8,:],f[10,:]])
df5=pd.DataFrame([f[0,:],f[1,:],f[2,:],f[3,:],f[5,:],f[6,:],f[7,:],f[8,:],f[10,:],bool2dec(dummy_df,ns,df.shape[1],1)])   # subnetwork with combination: sc1 = f11,f21,f31...f52...f92

# probability associated with fij
pc = np.ones(f.shape[0])
pc[0]=1.0
pc[1]=1.0
pc[2]=1.0
pc[3]=1.0
pc[4]=0.7
pc[5]=0.3
pc[6]=1.0
pc[7]=1.0
pc[8]=1.0
pc[9]=0.6
pc[10]=0.4


points_list_U1=list()     # transitions in decimal form with control u = 00
points_list_U2=list()     # transitions in decimal form with control u = 01
points_list_U3=list()     # transitions in decimal form with control u = 10
points_list_U4=list()     # transitions in decimal form with control u = 11
edge_weights_U1={}        # probabilities of transitions with control u = 00
edge_weights_U2={}        # probabilities of transitions with control u = 01
edge_weights_U3={}        # probabilities of transitions with control u = 10
edge_weights_U4={}        # probabilities of transitions with control u = 11

# notations indicating control chosen
control_dict={0:"u1=0,u2=0",
             1:"u1=0,u2=1",
             2:"u1=1,u2=0",
             3:"u1=1,u2=1",
            -1:"No Control"}

c = np.power(2,ns)
for i in range(np.power(2,ns)):                             # transitions are calculated in reference to the underlying dynamical equations and corresponding probabilities are stored
  points_list_U1.append((df[i].iloc[-1],df2[i].iloc[-1]))
  edge_weights_U1[points_list_U1[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U1.append((df[i].iloc[-1],df3[i].iloc[-1]))
  if points_list_U1[-1] in points_list_U1[0:len(points_list_U1)-1]:
    edge_weights_U1[points_list_U1[-1]]=str(float(edge_weights_U1[points_list_U1[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  else:
    edge_weights_U1[points_list_U1[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U1.append((df[i].iloc[-1],df4[i].iloc[-1]))
  if points_list_U1[-1] in points_list_U1[0:len(points_list_U1)-1]:
    edge_weights_U1[points_list_U1[-1]]=str(float(edge_weights_U1[points_list_U1[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U1[points_list_U1[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  points_list_U1.append((df[i].iloc[-1],df5[i].iloc[-1]))
  if points_list_U1[-1] in points_list_U1[0:len(points_list_U1)-1]:
    edge_weights_U1[points_list_U1[-1]]=str(float(edge_weights_U1[points_list_U1[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U1[points_list_U1[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))

  points_list_U2.append((df[i+c].iloc[-1],df2[i+c].iloc[-1]))
  edge_weights_U2[points_list_U2[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U2.append((df[i+c].iloc[-1],df3[i+c].iloc[-1]))
  if points_list_U2[-1] in points_list_U2[0:len(points_list_U2)-1]:
    edge_weights_U2[points_list_U2[-1]]=str(float(edge_weights_U2[points_list_U2[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  else:
    edge_weights_U2[points_list_U2[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U2.append((df[i+c].iloc[-1],df4[i+c].iloc[-1]))
  if points_list_U2[-1] in points_list_U2[0:len(points_list_U2)-1]:
    edge_weights_U2[points_list_U2[-1]]=str(float(edge_weights_U2[points_list_U2[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U2[points_list_U2[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  points_list_U2.append((df[i+c].iloc[-1],df5[i+c].iloc[-1]))
  if points_list_U2[-1] in points_list_U2[0:len(points_list_U2)-1]:
    edge_weights_U2[points_list_U2[-1]]=str(float(edge_weights_U2[points_list_U2[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U2[points_list_U2[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))

  points_list_U3.append((df[i+2*c].iloc[-1],df2[i+2*c].iloc[-1]))
  edge_weights_U3[points_list_U3[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U3.append((df[i+2*c].iloc[-1],df3[i+2*c].iloc[-1]))
  if points_list_U3[-1] in points_list_U3[0:len(points_list_U3)-1]:
    edge_weights_U3[points_list_U3[-1]]=str(float(edge_weights_U3[points_list_U3[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  else:
    edge_weights_U3[points_list_U3[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U3.append((df[i+2*c].iloc[-1],df4[i+2*c].iloc[-1]))
  if points_list_U3[-1] in points_list_U3[0:len(points_list_U3)-1]:
    edge_weights_U3[points_list_U3[-1]]=str(float(edge_weights_U3[points_list_U3[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U3[points_list_U3[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  points_list_U3.append((df[i+2*c].iloc[-1],df5[i+2*c].iloc[-1]))
  if points_list_U3[-1] in points_list_U3[0:len(points_list_U3)-1]:
    edge_weights_U3[points_list_U3[-1]]=str(float(edge_weights_U3[points_list_U3[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U3[points_list_U3[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))  
  
  points_list_U4.append((df[i+3*c].iloc[-1],df2[i+3*c].iloc[-1]))
  edge_weights_U4[points_list_U4[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U4.append((df[i+3*c].iloc[-1],df3[i+3*c].iloc[-1]))
  if points_list_U4[-1] in points_list_U4[0:len(points_list_U4)-1]:
    edge_weights_U4[points_list_U4[-1]]=str(float(edge_weights_U4[points_list_U4[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  else:
    edge_weights_U4[points_list_U4[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[9],2))
  points_list_U4.append((df[i+3*c].iloc[-1],df4[i+3*c].iloc[-1]))
  if points_list_U4[-1] in points_list_U4[0:len(points_list_U4)-1]:
    edge_weights_U4[points_list_U4[-1]]=str(float(edge_weights_U4[points_list_U4[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U4[points_list_U4[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[4]*pc[6]*pc[7]*pc[8]*pc[10],2))
  points_list_U4.append((df[i+3*c].iloc[-1],df5[i+3*c].iloc[-1]))
  if points_list_U4[-1] in points_list_U4[0:len(points_list_U4)-1]:
    edge_weights_U4[points_list_U4[-1]]=str(float(edge_weights_U4[points_list_U4[-1]])+np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))
  else:
    edge_weights_U4[points_list_U4[-1]]=str(np.round(pc[0]*pc[1]*pc[2]*pc[3]*pc[5]*pc[6]*pc[7]*pc[8]*pc[10],2))
  
# function to calculate possible attractors of the given PBCN
def find_Attractors(G,nx):
  number_of_attractor = nx.number_attracting_components(G)
  a_list = list(nx.attracting_components(G))
  return a_list

# Visualizing the graphs for u = 00
print("Graph with combination U=00")
GU1=nx.DiGraph()
GU1.add_edges_from(points_list_U1) 
plt.figure(figsize =(16, 8)) 
nx.draw_networkx(GU1, with_labels=False, node_color ='black')
plt.show()

# Calculating and saving attractors for individual control actions
attractor_set = []
a_calc = find_Attractors(GU1,nx)
attractor_set.append(a_calc)

# Visualizing the graphs for u = 01
print("Graph with combination U=01")
GU2=nx.DiGraph()
GU2.add_edges_from(points_list_U2) 
plt.figure(figsize =(16, 8)) 
nx.draw_networkx(GU2, with_labels=False, node_color ='black')
plt.show()

a_calc = find_Attractors(GU2,nx)
if a_calc not in attractor_set:
  attractor_set.append(a_calc)

# Visualizing the graphs for u = 10
print("Graph with combination U=10")
GU3=nx.DiGraph()
GU3.add_edges_from(points_list_U3) 
plt.figure(figsize =(16, 8)) 
nx.draw_networkx(GU3, with_labels=False, node_color ='black')
plt.show()

a_calc = find_Attractors(GU3,nx)
if a_calc not in attractor_set:
  attractor_set.append(a_calc)

# Visualizing the graphs for u = 11
print("Graph with combination U=11")
GU4=nx.DiGraph()
GU4.add_edges_from(points_list_U4) 
plt.figure(figsize =(16, 8)) 
nx.draw_networkx(GU4, with_labels=False, node_color ='black')
plt.show()

a_calc = find_Attractors(GU4,nx)
if a_calc not in attractor_set:
  attractor_set.append(a_calc)

# ---------------------->>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Creating PBCN Parameters <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<----------------------------
# Out:
# Graph with combination U=00
# Graph with combination U=01
# Graph with combination U=10
# Graph with combination U=11

# %% [markdown]
# # **Step 2: Implementing RL based control**
#
# For the current example, we implement the proposed QLRF algorithm.

# %%
# ---------------------->>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Defining and implementing RL control <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<----------------------------

# Model-free Reinforcement Learning

# Define parameters required for Q-learning
num_nodes=np.power(2,ns)
initial_state=np.random.choice(range(num_nodes-1))
goal=507                                            # desired attractor: decimal-507
undesired_goals=[4,68]                              # undesired attractors: decimal - 15406, 7216, 257, 14894, 6702
gamma=0.8                                           # discount factor: \gamma \in [0,1)
lr=0.8                                              # learning rate: \alpha \in (0,1]
EPSILON=0.1                                         # initialising \epsilon in \eplsion-greedy policy

# Environment variables
PTM=np.stack((edge_weights_U1,edge_weights_U2,edge_weights_U3,edge_weights_U4))   # Defining probability transitions matrix for function aprroximator learning

Q_algo=[]     # Initialize a dummy Q as a placeholder in greedy algo for QLRF
def greedy_policy(state,model_buff):
  data_buff=np.array([state_key[state]])
  data_regr=np.squeeze(model_buff.predict(data_buff))
  action_prob = np.ones(np.power(2,nc))*EPSILON/np.power(2,nc)         # define action probabilities as \epsilon/|A(s)|
  # choose best action to be a*=\underset{a\in A(s)}{\arg \max} Q
  best_action=np.squeeze(np.where(data_regr==np.max(data_regr)))
  if best_action.size>1:
    best_action = np.random.choice(best_action,size=1)
  action_prob[best_action]+=(1-EPSILON)                                # for a* set action probability = \epsilon/|A(s)| + (1-\epsilon)
  
  return action_prob

# Calc next_state on the basis of current state, and a greedy action for function approximator learning.
def calc_reward(current_state,next_state,action):
  reward_buff=[]
  if next_state == goal:
    reward_buff=15*float(PTM[action][current_state,next_state])
  elif next_state in undesired_goals:
    reward_buff=-1
  else:
    reward_buff = PTM[action][current_state,next_state]

  return float(reward_buff)

# Calc next_state on the basis of current state, and a greedy action for function approximator learning.
def calc_next_state(current_state,action):
  next_state_buff=[]
  reward_buff=[]
  for key1, key2 in PTM[action]:   # iter on both keys and values
    if key1==current_state:
      next_state_buff.append(key2)
      reward_buff.append(PTM[action][key1,key2])
  next_state = int(np.random.choice(next_state_buff,size=1))
  reward = calc_reward(current_state,next_state,action)

  return next_state, reward


# Define environment as: [current_state, next_state, action, reward] = env(current_state, Q_algo), where Q_algo is either QLRF.
def env(current_state,target_model):
  action_probabilities = greedy_policy(current_state,target_model)                            # calculate action probabilities using greedy policy
  action = np.random.choice(np.arange(len(action_probabilities)), p = action_probabilities)   # calculate action
  if action.size > 1:                                     # if there are multiple actions choose any one randomly and for the chosen random action, choose single next_state if multiple transitions are possible
    action = int(np.random.choice(action,size=1))
    next_state, reward = calc_next_state(current_state, action)
  else:
    next_state, reward = calc_next_state(current_state, action)

  return np.array([current_state,next_state,action,reward])

# set a seed for rehearsing the results
seed = 5732
np.random.seed(seed)

# initialise QLRF regressor with related parameters as per the number of samples to be inspected
# max_depth = 4
regressor = MultiOutputRegressor(RandomForestRegressor(n_estimators=4,
                                                            # max_depth=max_depth,
                                                            random_state=14, warm_start=True))
# Initialise Standard scaler for data to be learnt
sc = StandardScaler()

Q=np.zeros([np.power(2,ns),np.power(2,nc)]) # Initialize Q table to zeros with dimensions defined by states-action pairs
# QLRF algorithm
def QLRF(RANDOM_TRANSITIONS_DATA_buff,regressor):
  
  Q_pred_qrf = np.zeros(Q.shape)                                        # Initialize Q to zeros
    
  # generate D=(xn,yn) from state-action-value pairs from replay buffer
  data_buff = np.squeeze(RANDOM_TRANSITIONS_DATA_buff)
  X = np.array([list(item) for item in np.array(data_buff[:,2])])
  y = np.array([item for item in data_buff[:,3]])

  # Standardized the data for good predictions
  X = sc.fit_transform(X)
  Y = sc.fit_transform(y)

  # Fit the QLRF forest using the data extracted from Experience Replay buffer
  regressor = MultiOutputRegressor(RandomForestRegressor(n_estimators=2, random_state=14, warm_start=True))
  regressor.fit(X, Y)

  # generate predictions using fitted random forest model and use inverse transform to generate unscaled original values
  y_pred = regressor.predict(X)
  y_pred=sc.inverse_transform(y_pred)

  # remove rewards lower than or higher than a certain threshold in order to avoid bad predictions
  for k in range(y_pred.shape[0]):
    if (y_pred[k,:].all()>REWARD_LB) and (y_pred[k,:].all()<=REWARD_UB):
      Q_pred_qrf[int(data_buff[k,0]),:] = y_pred[k,:]
  
  return Q_pred_qrf,regressor

# ------------------------>>>>>>>>>>>>>>>>> Training Module <<<<<<<<<<<<<<<<----------------------------
start_time = time.time()                                            # start the timer to time overall code execution for all the three algorithms to train

# Initialize overall normalized scores
scores_QLRF = []
# Initialize predict (Q) and target (\hat{Q}) for QRLF
Q_target_QLRF = np.zeros([np.power(2,ns),np.power(2,nc)])
Q_predict_QLRF = np.zeros([np.power(2,ns),np.power(2,nc)])
# Define parameters for exploration-exploitation type learning starting from complete exploration to near exploitation of target Q values.
EPSILON = 1.0
EPSILON_DECAY_RATE = 0.95
EPSILON_MIN = 0.05
EPSILON_DECAY_ITER = 50
# set maximum replay buffer capacity or RB_{cap}
REPLAY_BUFFER_MAX = 4
# set number of parameters to be stored in replay buffer; i.e., current_state, next_state, action, reward
no_of_params_RB = 4
# initialize replay buffers QLRF
REPLAY_BUFFER_QLRF = np.zeros([REPLAY_BUFFER_MAX,no_of_params_RB])
# set maximum iterations to train and batch size to be sampled
BATCH = 4
MAX_ITER = np.power(2,ns) + int(np.power(2,ns)/REPLAY_BUFFER_MAX) + (REPLAY_BUFFER_MAX-BATCH)*REPLAY_BUFFER_MAX + 5000 # Optimal iterations as number of states + (number of states/RB_{cap}) + extra steps, if required.
# initialize randomly sampled dataset for both the algorithms
RANDOM_TRANSITIONS_QLRF = np.zeros([BATCH,no_of_params_RB])
# define upper and lower bounds on rewards achieved, a very high negative and positive reward is chosen assuming there is no bad data predicted.
REWARD_LB = -1000
REWARD_UB = 1000
# initialize random transitions dataset D_i \in random_transitions dataset D according to defined batch size.
RANDOM_TRANSITIONS_DATA2 = []
# initialize target for QLRF
TARGET2 = np.zeros([BATCH,np.power(2,nc)])
# initialize losses for QLRF
LOSS2 = np.zeros([BATCH,1])
# initialize counts and state_key for corresponding states and action boolean values
cnt = 0
idx_cnt = 0
state_key = list(itertools.product([0, 1], repeat=ns))
state_key_c = list(itertools.product([0, 1], repeat=nc))
# initialise data buffer predicted by the models for calculating Q_{max} in each step
Q_target_data_buff=0
Q_target_data_buff_X=0

# initialise QLRF regressor with random data
X_dummy=state_key[:10]
Y_dummy=np.random.rand(10,np.power(2,nc))
regressor.fit(X_dummy,Y_dummy)

for j in range(MAX_ITER):
  # choose random current_state in every iterations and generated data for training QLRF using Q values
  current_state = (np.power(2,ns)-1)-j%np.power(2,ns)           # Please make a note that here we use reversed values, as undesired attractors [4,68] at start generate huge spikes.

  # generate replay buffers for DQN and QLRF learning
  REPLAY_BUFFER_QLRF[idx_cnt, :] = env(current_state, regressor)
  idx_cnt+=1
  cnt+=1

  # reduce epsilon every training step so as to maintain exploration-exploitation
  if EPSILON >= EPSILON_MIN and cnt%EPSILON_DECAY_ITER==0:
    EPSILON*=EPSILON_DECAY_RATE
  
  # iteratre until replay buffer is completely filled and once the data is available train QLRF models
  if cnt%REPLAY_BUFFER_MAX==0 and cnt!=0:
    
    idx = np.random.randint(REPLAY_BUFFER_MAX, size=BATCH)          # choose random indexes of size batch from replay buffer 
    # generate random transitions sample dataset for training 
    RANDOM_TRANSITIONS_QLRF = REPLAY_BUFFER_QLRF[idx, :]

    # for all the values in random transitions dataset train DQN and QLRF models
    for l in range(BATCH):
      # for QLRF we choose exploring all the states at any given state value allowing to fasten the training process
      for k in range(np.power(2,nc)):
        # with current state-action pairs generate target values for learning
        next_state, reward = calc_next_state(int(RANDOM_TRANSITIONS_QLRF[l,0]),k)

        # if next state == terminal: --> target = maximum reward else: --> target = r+\gamma \underset{a \in A(s)}{\arg \max} Q(s,a)
        if next_state == goal:
          TARGET2[l,k] = calc_reward(int(RANDOM_TRANSITIONS_QLRF[l,0]),next_state,k)
        else:
          # calculate Q_{max} using the best action being in current state
          Q_target_data_buff_X=np.array([state_key[int(next_state)]])
          Q_target_data_buff=np.squeeze(regressor.predict(Q_target_data_buff_X))
          # max_index=np.squeeze(np.argmax(Q_target_data_buff))
          max_index=np.squeeze(np.where(Q_target_data_buff==np.max(Q_target_data_buff)))

          if max_index.size > 1:
              max_index = int(np.random.choice(max_index, size = 1))
          else:
              max_index = int(max_index)
          max_value = Q_target_data_buff[max_index]

          # target = r+\gamma \underset{a \in A(s)}{\arg \max} Q(s,a)
          TARGET2[l,k] = reward+gamma*(max_value)

      # LOSS = \sum (Q_predicted-Target)^2. Although, we avoid calculating explicit loss here and allow regressor algorithms to employ MSE loss, which is the same. 
      # random transitions data comprises of current_state, action , binary key for transitions, target. Altough, all others are dummy except binary key and target are the ones used for training.   
      RANDOM_TRANSITIONS_DATA2.append(np.array([RANDOM_TRANSITIONS_QLRF[l,0],RANDOM_TRANSITIONS_QLRF[l,2],state_key[int(RANDOM_TRANSITIONS_QLRF[l,0])],TARGET2[l,:]]))        

    # predict Q values using QLRF algorithm and store values for computing MDP score.
    Q_predict_QLRF,regressor=QLRF(RANDOM_TRANSITIONS_DATA2,regressor)
    for l in range(Q_predict_QLRF.shape[0]):
      for k in range(Q_predict_QLRF.shape[1]):
        if Q_predict_QLRF[l,k]!=0:                  # update target Q values using newer values in predict Q values and avoid bad predictions
          Q_target_QLRF[l,k] = Q_predict_QLRF[l,k] 

    # flush all the data from replay buffer and randomly sampled dataset
    idx_cnt = 0
    REPLAY_BUFFER_QLRF = np.zeros([REPLAY_BUFFER_MAX,no_of_params_RB])
    RANDOM_TRANSITIONS_DATA2 = []

    # calculate normalized rewards or scores for individual algorithms
    if (np.max(Q_target_QLRF) > 0):
      scores_pred = ((np.sum(Q_target_QLRF/np.max(Q_target_QLRF)*100)))
    else:
      scores_pred=0
    scores_QLRF.append(scores_pred)

    # print overall progress of the training process.
    print(np.round((j/MAX_ITER)*100,2),'% complete.')
  

# print total time taken for the overall training
print('Total time taken for training of all the three algorithms')
print("--- %s seconds ---" % (time.time() - start_time))

# generate normalized score from successive steps for peer-to-peer comparisons
scores_QLRF = scores_QLRF/np.max(scores_QLRF)

# # generate a linear x-space for plotting
t = np.linspace(0, 1, len(scores_QLRF))

# # visualize the data
plt.plot(t, scores_QLRF, label='QLRF', color = 'green')
plt.xlabel('Normalized Epochs')
plt.ylabel('Normalized Rewards')
plt.legend()
plt.show()

# ------------------------>>>>>>>>>>>>>>>>> Training Module <<<<<<<<<<<<<<<<----------------------------

# ---------------------->>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Defining and implementing RL control <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<----------------------------
# Out:
# 0.05 % complete.
# 0.12 % complete.
# 0.2 % complete.
# 0.27 % complete.
# 0.34 % complete.
# 0.41 % complete.
# 0.48 % complete.
# 0.55 % complete.
# 0.62 % complete.
# 0.69 % complete.
# 0.76 % complete.
# 0.83 % complete.
# 0.9 % complete.
# 0.98 % complete.
# 1.05 % complete.
# 1.12 % complete.
# 1.19 % complete.
# 1.26 % complete.
# 1.33 % complete.
# 1.4 % complete.
# 1.47 % complete.
# 1.54 % complete.
# 1.61 % complete.
# 1.68 % complete.
# 1.76 % complete.
# 1.83 % complete.
# 1.9 % complete.
# 1.97 % complete.
# 2.04 % complete.
# 2.11 % complete.
# 2.18 % complete.
# 2.25 % complete.
# 2.32 % complete.
# 2.39 % complete.
# 2.46 % complete.
# 2.54 % complete.
# 2.61 % complete.
# 2.68 % complete.
# 2.75 % complete.
# 2.82 % complete.
# 2.89 % complete.
# 2.96 % complete.
# 3.03 % complete.
# 3.1 % complete.
# 3.17 % complete.
# 3.24 % complete.
# 3.32 % complete.
# 3.39 % complete.
# 3.46 % complete.
# 3.53 % complete.
# 3.6 % complete.
# 3.67 % complete.
# 3.74 % complete.
# 3.81 % complete.
# 3.88 % complete.
# 3.95 % complete.
# 4.02 % complete.
# 4.1 % complete.
# 4.17 % complete.
# 4.24 % complete.
# 4.31 % complete.
# 4.38 % complete.
# 4.45 % complete.
# 4.52 % complete.
# 4.59 % complete.
# 4.66 % complete.
# 4.73 % complete.
# 4.8 % complete.
# 4.88 % complete.
# 4.95 % complete.
# 5.02 % complete.
# 5.09 % complete.
# 5.16 % complete.
# 5.23 % complete.
# 5.3 % complete.
# 5.37 % complete.
# 5.44 % complete.
# 5.51 % complete.
# 5.59 % complete.
# 5.66 % complete.
# 5.73 % complete.
# 5.8 % complete.
# 5.87 % complete.
# 5.94 % complete.
# 6.01 % complete.
# 6.08 % complete.
# 6.15 % complete.
# 6.22 % complete.
# 6.29 % complete.
# 6.37 % complete.
# 6.44 % complete.
# 6.51 % complete.
# 6.58 % complete.
# 6.65 % complete.
# 6.72 % complete.
# 6.79 % complete.
# 6.86 % complete.
# 6.93 % complete.
# 7.0 % complete.
# 7.07 % complete.
# 7.15 % complete.
# 7.22 % complete.
# 7.29 % complete.
# 7.36 % complete.
# 7.43 % complete.
# 7.5 % complete.
# 7.57 % complete.
# 7.64 % complete.
# 7.71 % complete.
# 7.78 % complete.
# 7.85 % complete.
# 7.93 % complete.
# 8.0 % complete.
# 8.07 % complete.
# 8.14 % complete.
# 8.21 % complete.
# 8.28 % complete.
# 8.35 % complete.
# 8.42 % complete.
# 8.49 % complete.
# 8.56 % complete.
# 8.63 % complete.
# 8.71 % complete.
# 8.78 % complete.
# 8.85 % complete.
# 8.92 % complete.
# 8.99 % complete.
# 9.06 % complete.
# 9.13 % complete.
# 9.2 % complete.
# 9.27 % complete.
# 9.34 % complete.
# 9.41 % complete.
# 9.49 % complete.
# 9.56 % complete.
# 9.63 % complete.
# 9.7 % complete.
# 9.77 % complete.
# 9.84 % complete.
# 9.91 % complete.
# 9.98 % complete.
# 10.05 % complete.
# 10.12 % complete.
# 10.2 % complete.
# 10.27 % complete.
# 10.34 % complete.
# 10.41 % complete.
# 10.48 % complete.
# 10.55 % complete.
# 10.62 % complete.
# 10.69 % complete.
# 10.76 % complete.
# 10.83 % complete.
# 10.9 % complete.
# 10.98 % complete.
# 11.05 % complete.
# 11.12 % complete.
# 11.19 % complete.
# 11.26 % complete.
# 11.33 % complete.
# 11.4 % complete.
# 11.47 % complete.
# 11.54 % complete.
# 11.61 % complete.
# 11.68 % complete.
# 11.76 % complete.
# 11.83 % complete.
# 11.9 % complete.
# 11.97 % complete.
# 12.04 % complete.
# 12.11 % complete.
# 12.18 % complete.
# 12.25 % complete.
# 12.32 % complete.
# 12.39 % complete.
# 12.46 % complete.
# 12.54 % complete.
# 12.61 % complete.
# 12.68 % complete.
# 12.75 % complete.
# 12.82 % complete.
# 12.89 % complete.
# 12.96 % complete.
# 13.03 % complete.
# 13.1 % complete.
# 13.17 % complete.
# 13.24 % complete.
# 13.32 % complete.
# 13.39 % complete.
# 13.46 % complete.
# 13.53 % complete.
# 13.6 % complete.
# 13.67 % complete.
# 13.74 % complete.
# 13.81 % complete.
# 13.88 % complete.
# 13.95 % complete.
# 14.02 % complete.
# 14.1 % complete.
# 14.17 % complete.
# 14.24 % complete.
# 14.31 % complete.
# 14.38 % complete.
# 14.45 % complete.
# 14.52 % complete.
# 14.59 % complete.
# 14.66 % complete.
# 14.73 % complete.
# 14.8 % complete.
# 14.88 % complete.
# 14.95 % complete.
# 15.02 % complete.
# 15.09 % complete.
# 15.16 % complete.
# 15.23 % complete.
# 15.3 % complete.
# 15.37 % complete.
# 15.44 % complete.
# 15.51 % complete.
# 15.59 % complete.
# 15.66 % complete.
# 15.73 % complete.
# 15.8 % complete.
# 15.87 % complete.
# 15.94 % complete.
# 16.01 % complete.
# 16.08 % complete.
# 16.15 % complete.
# 16.22 % complete.
# 16.29 % complete.
# 16.37 % complete.
# 16.44 % complete.
# 16.51 % complete.
# 16.58 % complete.
# 16.65 % complete.
# 16.72 % complete.
# 16.79 % complete.
# 16.86 % complete.
# 16.93 % complete.
# 17.0 % complete.
# 17.07 % complete.
# 17.15 % complete.
# 17.22 % complete.
# 17.29 % complete.
# 17.36 % complete.
# 17.43 % complete.
# 17.5 % complete.
# 17.57 % complete.
# 17.64 % complete.
# 17.71 % complete.
# 17.78 % complete.
# 17.85 % complete.
# 17.93 % complete.
# 18.0 % complete.
# 18.07 % complete.
# 18.14 % complete.
# 18.21 % complete.
# 18.28 % complete.
# 18.35 % complete.
# 18.42 % complete.
# 18.49 % complete.
# 18.56 % complete.
# 18.63 % complete.
# 18.71 % complete.
# 18.78 % complete.
# 18.85 % complete.
# 18.92 % complete.
# 18.99 % complete.
# 19.06 % complete.
# 19.13 % complete.
# 19.2 % complete.
# 19.27 % complete.
# 19.34 % complete.
# 19.41 % complete.
# 19.49 % complete.
# 19.56 % complete.
# 19.63 % complete.
# 19.7 % complete.
# 19.77 % complete.
# 19.84 % complete.
# 19.91 % complete.
# 19.98 % complete.
# 20.05 % complete.
# 20.12 % complete.
# 20.2 % complete.
# 20.27 % complete.
# 20.34 % complete.
# 20.41 % complete.
# 20.48 % complete.
# 20.55 % complete.
# 20.62 % complete.
# 20.69 % complete.
# 20.76 % complete.
# 20.83 % complete.
# 20.9 % complete.
# 20.98 % complete.
# 21.05 % complete.
# 21.12 % complete.
# 21.19 % complete.
# 21.26 % complete.
# 21.33 % complete.
# 21.4 % complete.
# 21.47 % complete.
# 21.54 % complete.
# 21.61 % complete.
# 21.68 % complete.
# 21.76 % complete.
# 21.83 % complete.
# 21.9 % complete.
# 21.97 % complete.
# 22.04 % complete.
# 22.11 % complete.
# 22.18 % complete.
# 22.25 % complete.
# 22.32 % complete.
# 22.39 % complete.
# 22.46 % complete.
# 22.54 % complete.
# 22.61 % complete.
# 22.68 % complete.
# 22.75 % complete.
# 22.82 % complete.
# 22.89 % complete.
# 22.96 % complete.
# 23.03 % complete.
# 23.1 % complete.
# 23.17 % complete.
# 23.24 % complete.
# 23.32 % complete.
# 23.39 % complete.
# 23.46 % complete.
# 23.53 % complete.
# 23.6 % complete.
# 23.67 % complete.
# 23.74 % complete.
# 23.81 % complete.
# 23.88 % complete.
# 23.95 % complete.
# 24.02 % complete.
# 24.1 % complete.
# 24.17 % complete.
# 24.24 % complete.
# 24.31 % complete.
# 24.38 % complete.
# 24.45 % complete.
# 24.52 % complete.
# 24.59 % complete.
# 24.66 % complete.
# 24.73 % complete.
# 24.8 % complete.
# 24.88 % complete.
# 24.95 % complete.
# 25.02 % complete.
# 25.09 % complete.
# 25.16 % complete.
# 25.23 % complete.
# 25.3 % complete.
# 25.37 % complete.
# 25.44 % complete.
# 25.51 % complete.
# 25.59 % complete.
# 25.66 % complete.
# 25.73 % complete.
# 25.8 % complete.
# 25.87 % complete.
# 25.94 % complete.
# 26.01 % complete.
# 26.08 % complete.
# 26.15 % complete.
# 26.22 % complete.
# 26.29 % complete.
# 26.37 % complete.
# 26.44 % complete.
# 26.51 % complete.
# 26.58 % complete.
# 26.65 % complete.
# 26.72 % complete.
# 26.79 % complete.
# 26.86 % complete.
# 26.93 % complete.
# 27.0 % complete.
# 27.07 % complete.
# 27.15 % complete.
# 27.22 % complete.
# 27.29 % complete.
# 27.36 % complete.
# 27.43 % complete.
# 27.5 % complete.
# 27.57 % complete.
# 27.64 % complete.
# 27.71 % complete.
# 27.78 % complete.
# 27.85 % complete.
# 27.93 % complete.
# 28.0 % complete.
# 28.07 % complete.
# 28.14 % complete.
# 28.21 % complete.
# 28.28 % complete.
# 28.35 % complete.
# 28.42 % complete.
# 28.49 % complete.
# 28.56 % complete.
# 28.63 % complete.
# 28.71 % complete.
# 28.78 % complete.
# 28.85 % complete.
# 28.92 % complete.
# 28.99 % complete.
# 29.06 % complete.
# 29.13 % complete.
# 29.2 % complete.
# 29.27 % complete.
# 29.34 % complete.
# 29.41 % complete.
# 29.49 % complete.
# 29.56 % complete.
# 29.63 % complete.
# 29.7 % complete.
# 29.77 % complete.
# 29.84 % complete.
# 29.91 % complete.
# 29.98 % complete.
# 30.05 % complete.
# 30.12 % complete.
# 30.2 % complete.
# 30.27 % complete.
# 30.34 % complete.
# 30.41 % complete.
# 30.48 % complete.
# 30.55 % complete.
# 30.62 % complete.
# 30.69 % complete.
# 30.76 % complete.
# 30.83 % complete.
# 30.9 % complete.
# 30.98 % complete.
# 31.05 % complete.
# 31.12 % complete.
# 31.19 % complete.
# 31.26 % complete.
# 31.33 % complete.
# 31.4 % complete.
# 31.47 % complete.
# 31.54 % complete.
# 31.61 % complete.
# 31.68 % complete.
# 31.76 % complete.
# 31.83 % complete.
# 31.9 % complete.
# 31.97 % complete.
# 32.04 % complete.
# 32.11 % complete.
# 32.18 % complete.
# 32.25 % complete.
# 32.32 % complete.
# 32.39 % complete.
# 32.46 % complete.
# 32.54 % complete.
# 32.61 % complete.
# 32.68 % complete.
# 32.75 % complete.
# 32.82 % complete.
# 32.89 % complete.
# 32.96 % complete.
# 33.03 % complete.
# 33.1 % complete.
# 33.17 % complete.
# 33.24 % complete.
# 33.32 % complete.
# 33.39 % complete.
# 33.46 % complete.
# 33.53 % complete.
# 33.6 % complete.
# 33.67 % complete.
# 33.74 % complete.
# 33.81 % complete.
# 33.88 % complete.
# 33.95 % complete.
# 34.02 % complete.
# 34.1 % complete.
# 34.17 % complete.
# 34.24 % complete.
# 34.31 % complete.
# 34.38 % complete.
# 34.45 % complete.
# 34.52 % complete.
# 34.59 % complete.
# 34.66 % complete.
# 34.73 % complete.
# 34.8 % complete.
# 34.88 % complete.
# 34.95 % complete.
# 35.02 % complete.
# 35.09 % complete.
# 35.16 % complete.
# 35.23 % complete.
# 35.3 % complete.
# 35.37 % complete.
# 35.44 % complete.
# 35.51 % complete.
# 35.59 % complete.
# 35.66 % complete.
# 35.73 % complete.
# 35.8 % complete.
# 35.87 % complete.
# 35.94 % complete.
# 36.01 % complete.
# 36.08 % complete.
# 36.15 % complete.
# 36.22 % complete.
# 36.29 % complete.
# 36.37 % complete.
# 36.44 % complete.
# 36.51 % complete.
# 36.58 % complete.
# 36.65 % complete.
# 36.72 % complete.
# 36.79 % complete.
# 36.86 % complete.
# 36.93 % complete.
# 37.0 % complete.
# 37.07 % complete.
# 37.15 % complete.
# 37.22 % complete.
# 37.29 % complete.
# 37.36 % complete.
# 37.43 % complete.
# 37.5 % complete.
# 37.57 % complete.
# 37.64 % complete.
# 37.71 % complete.
# 37.78 % complete.
# 37.85 % complete.
# 37.93 % complete.
# 38.0 % complete.
# 38.07 % complete.
# 38.14 % complete.
# 38.21 % complete.
# 38.28 % complete.
# 38.35 % complete.
# 38.42 % complete.
# 38.49 % complete.
# 38.56 % complete.
# 38.63 % complete.
# 38.71 % complete.
# 38.78 % complete.
# 38.85 % complete.
# 38.92 % complete.
# 38.99 % complete.
# 39.06 % complete.
# 39.13 % complete.
# 39.2 % complete.
# 39.27 % complete.
# 39.34 % complete.
# 39.41 % complete.
# 39.49 % complete.
# 39.56 % complete.
# 39.63 % complete.
# 39.7 % complete.
# 39.77 % complete.
# 39.84 % complete.
# 39.91 % complete.
# 39.98 % complete.
# 40.05 % complete.
# 40.12 % complete.
# 40.2 % complete.
# 40.27 % complete.
# 40.34 % complete.
# 40.41 % complete.
# 40.48 % complete.
# 40.55 % complete.
# 40.62 % complete.
# 40.69 % complete.
# 40.76 % complete.
# 40.83 % complete.
# 40.9 % complete.
# 40.98 % complete.
# 41.05 % complete.
# 41.12 % complete.
# 41.19 % complete.
# 41.26 % complete.
# 41.33 % complete.
# 41.4 % complete.
# 41.47 % complete.
# 41.54 % complete.
# 41.61 % complete.
# 41.68 % complete.
# 41.76 % complete.
# 41.83 % complete.
# 41.9 % complete.
# 41.97 % complete.
# 42.04 % complete.
# 42.11 % complete.
# 42.18 % complete.
# 42.25 % complete.
# 42.32 % complete.
# 42.39 % complete.
# 42.46 % complete.
# 42.54 % complete.
# 42.61 % complete.
# 42.68 % complete.
# 42.75 % complete.
# 42.82 % complete.
# 42.89 % complete.
# 42.96 % complete.
# 43.03 % complete.
# 43.1 % complete.
# 43.17 % complete.
# 43.24 % complete.
# 43.32 % complete.
# 43.39 % complete.
# 43.46 % complete.
# 43.53 % complete.
# 43.6 % complete.
# 43.67 % complete.
# 43.74 % complete.
# 43.81 % complete.
# 43.88 % complete.
# 43.95 % complete.
# 44.02 % complete.
# 44.1 % complete.
# 44.17 % complete.
# 44.24 % complete.
# 44.31 % complete.
# 44.38 % complete.
# 44.45 % complete.
# 44.52 % complete.
# 44.59 % complete.
# 44.66 % complete.
# 44.73 % complete.
# 44.8 % complete.
# 44.88 % complete.
# 44.95 % complete.
# 45.02 % complete.
# 45.09 % complete.
# 45.16 % complete.
# 45.23 % complete.
# 45.3 % complete.
# 45.37 % complete.
# 45.44 % complete.
# 45.51 % complete.
# 45.59 % complete.
# 45.66 % complete.
# 45.73 % complete.
# 45.8 % complete.
# 45.87 % complete.
# 45.94 % complete.
# 46.01 % complete.
# 46.08 % complete.
# 46.15 % complete.
# 46.22 % complete.
# 46.29 % complete.
# 46.37 % complete.
# 46.44 % complete.
# 46.51 % complete.
# 46.58 % complete.
# 46.65 % complete.
# 46.72 % complete.
# 46.79 % complete.
# 46.86 % complete.
# 46.93 % complete.
# 47.0 % complete.
# 47.07 % complete.
# 47.15 % complete.
# 47.22 % complete.
# 47.29 % complete.
# 47.36 % complete.
# 47.43 % complete.
# 47.5 % complete.
# 47.57 % complete.
# 47.64 % complete.
# 47.71 % complete.
# 47.78 % complete.
# 47.85 % complete.
# 47.93 % complete.
# 48.0 % complete.
# 48.07 % complete.
# 48.14 % complete.
# 48.21 % complete.
# 48.28 % complete.
# 48.35 % complete.
# 48.42 % complete.
# 48.49 % complete.
# 48.56 % complete.
# 48.63 % complete.
# 48.71 % complete.
# 48.78 % complete.
# 48.85 % complete.
# 48.92 % complete.
# 48.99 % complete.
# 49.06 % complete.
# 49.13 % complete.
# 49.2 % complete.
# 49.27 % complete.
# 49.34 % complete.
# 49.41 % complete.
# 49.49 % complete.
# 49.56 % complete.
# 49.63 % complete.
# 49.7 % complete.
# 49.77 % complete.
# 49.84 % complete.
# 49.91 % complete.
# 49.98 % complete.
# 50.05 % complete.
# 50.12 % complete.
# 50.2 % complete.
# 50.27 % complete.
# 50.34 % complete.
# 50.41 % complete.
# 50.48 % complete.
# 50.55 % complete.
# 50.62 % complete.
# 50.69 % complete.
# 50.76 % complete.
# 50.83 % complete.
# 50.9 % complete.
# 50.98 % complete.
# 51.05 % complete.
# 51.12 % complete.
# 51.19 % complete.
# 51.26 % complete.
# 51.33 % complete.
# 51.4 % complete.
# 51.47 % complete.
# 51.54 % complete.
# 51.61 % complete.
# 51.68 % complete.
# 51.76 % complete.
# 51.83 % complete.
# 51.9 % complete.
# 51.97 % complete.
# 52.04 % complete.
# 52.11 % complete.
# 52.18 % complete.
# 52.25 % complete.
# 52.32 % complete.
# 52.39 % complete.
# 52.46 % complete.
# 52.54 % complete.
# 52.61 % complete.
# 52.68 % complete.
# 52.75 % complete.
# 52.82 % complete.
# 52.89 % complete.
# 52.96 % complete.
# 53.03 % complete.
# 53.1 % complete.
# 53.17 % complete.
# 53.24 % complete.
# 53.32 % complete.
# 53.39 % complete.
# 53.46 % complete.
# 53.53 % complete.
# 53.6 % complete.
# 53.67 % complete.
# 53.74 % complete.
# 53.81 % complete.
# 53.88 % complete.
# 53.95 % complete.
# 54.02 % complete.
# 54.1 % complete.
# 54.17 % complete.
# 54.24 % complete.
# 54.31 % complete.
# 54.38 % complete.
# 54.45 % complete.
# 54.52 % complete.
# 54.59 % complete.
# 54.66 % complete.
# 54.73 % complete.
# 54.8 % complete.
# 54.88 % complete.
# 54.95 % complete.
# 55.02 % complete.
# 55.09 % complete.
# 55.16 % complete.
# 55.23 % complete.
# 55.3 % complete.
# 55.37 % complete.
# 55.44 % complete.
# 55.51 % complete.
# 55.59 % complete.
# 55.66 % complete.
# 55.73 % complete.
# 55.8 % complete.
# 55.87 % complete.
# 55.94 % complete.
# 56.01 % complete.
# 56.08 % complete.
# 56.15 % complete.
# 56.22 % complete.
# 56.29 % complete.
# 56.37 % complete.
# 56.44 % complete.
# 56.51 % complete.
# 56.58 % complete.
# 56.65 % complete.
# 56.72 % complete.
# 56.79 % complete.
# 56.86 % complete.
# 56.93 % complete.
# 57.0 % complete.
# 57.07 % complete.
# 57.15 % complete.
# 57.22 % complete.
# 57.29 % complete.
# 57.36 % complete.
# 57.43 % complete.
# 57.5 % complete.
# 57.57 % complete.
# 57.64 % complete.
# 57.71 % complete.
# 57.78 % complete.
# 57.85 % complete.
# 57.93 % complete.
# 58.0 % complete.
# 58.07 % complete.
# 58.14 % complete.
# 58.21 % complete.
# 58.28 % complete.
# 58.35 % complete.
# 58.42 % complete.
# 58.49 % complete.
# 58.56 % complete.
# 58.63 % complete.
# 58.71 % complete.
# 58.78 % complete.
# 58.85 % complete.
# 58.92 % complete.
# 58.99 % complete.
# 59.06 % complete.
# 59.13 % complete.
# 59.2 % complete.
# 59.27 % complete.
# 59.34 % complete.
# 59.41 % complete.
# 59.49 % complete.
# 59.56 % complete.
# 59.63 % complete.
# 59.7 % complete.
# 59.77 % complete.
# 59.84 % complete.
# 59.91 % complete.
# 59.98 % complete.
# 60.05 % complete.
# 60.12 % complete.
# 60.2 % complete.
# 60.27 % complete.
# 60.34 % complete.
# 60.41 % complete.
# 60.48 % complete.
# 60.55 % complete.
# 60.62 % complete.
# 60.69 % complete.
# 60.76 % complete.
# 60.83 % complete.
# 60.9 % complete.
# 60.98 % complete.
# 61.05 % complete.
# 61.12 % complete.
# 61.19 % complete.
# 61.26 % complete.
# 61.33 % complete.
# 61.4 % complete.
# 61.47 % complete.
# 61.54 % complete.
# 61.61 % complete.
# 61.68 % complete.
# 61.76 % complete.
# 61.83 % complete.
# 61.9 % complete.
# 61.97 % complete.
# 62.04 % complete.
# 62.11 % complete.
# 62.18 % complete.
# 62.25 % complete.
# 62.32 % complete.
# 62.39 % complete.
# 62.46 % complete.
# 62.54 % complete.
# 62.61 % complete.
# 62.68 % complete.
# 62.75 % complete.
# 62.82 % complete.
# 62.89 % complete.
# 62.96 % complete.
# 63.03 % complete.
# 63.1 % complete.
# 63.17 % complete.
# 63.24 % complete.
# 63.32 % complete.
# 63.39 % complete.
# 63.46 % complete.
# 63.53 % complete.
# 63.6 % complete.
# 63.67 % complete.
# 63.74 % complete.
# 63.81 % complete.
# 63.88 % complete.
# 63.95 % complete.
# 64.02 % complete.
# 64.1 % complete.
# 64.17 % complete.
# 64.24 % complete.
# 64.31 % complete.
# 64.38 % complete.
# 64.45 % complete.
# 64.52 % complete.
# 64.59 % complete.
# 64.66 % complete.
# 64.73 % complete.
# 64.8 % complete.
# 64.88 % complete.
# 64.95 % complete.
# 65.02 % complete.
# 65.09 % complete.
# 65.16 % complete.
# 65.23 % complete.
# 65.3 % complete.
# 65.37 % complete.
# 65.44 % complete.
# 65.51 % complete.
# 65.59 % complete.
# 65.66 % complete.
# 65.73 % complete.
# 65.8 % complete.
# 65.87 % complete.
# 65.94 % complete.
# 66.01 % complete.
# 66.08 % complete.
# 66.15 % complete.
# 66.22 % complete.
# 66.29 % complete.
# 66.37 % complete.
# 66.44 % complete.
# 66.51 % complete.
# 66.58 % complete.
# 66.65 % complete.
# 66.72 % complete.
# 66.79 % complete.
# 66.86 % complete.
# 66.93 % complete.
# 67.0 % complete.
# 67.07 % complete.
# 67.15 % complete.
# 67.22 % complete.
# 67.29 % complete.
# 67.36 % complete.
# 67.43 % complete.
# 67.5 % complete.
# 67.57 % complete.
# 67.64 % complete.
# 67.71 % complete.
# 67.78 % complete.
# 67.85 % complete.
# 67.93 % complete.
# 68.0 % complete.
# 68.07 % complete.
# 68.14 % complete.
# 68.21 % complete.
# 68.28 % complete.
# 68.35 % complete.
# 68.42 % complete.
# 68.49 % complete.
# 68.56 % complete.
# 68.63 % complete.
# 68.71 % complete.
# 68.78 % complete.
# 68.85 % complete.
# 68.92 % complete.
# 68.99 % complete.
# 69.06 % complete.
# 69.13 % complete.
# 69.2 % complete.
# 69.27 % complete.
# 69.34 % complete.
# 69.41 % complete.
# 69.49 % complete.
# 69.56 % complete.
# 69.63 % complete.
# 69.7 % complete.
# 69.77 % complete.
# 69.84 % complete.
# 69.91 % complete.
# 69.98 % complete.
# 70.05 % complete.
# 70.12 % complete.
# 70.2 % complete.
# 70.27 % complete.
# 70.34 % complete.
# 70.41 % complete.
# 70.48 % complete.
# 70.55 % complete.
# 70.62 % complete.
# 70.69 % complete.
# 70.76 % complete.
# 70.83 % complete.
# 70.9 % complete.
# 70.98 % complete.
# 71.05 % complete.
# 71.12 % complete.
# 71.19 % complete.
# 71.26 % complete.
# 71.33 % complete.
# 71.4 % complete.
# 71.47 % complete.
# 71.54 % complete.
# 71.61 % complete.
# 71.68 % complete.
# 71.76 % complete.
# 71.83 % complete.
# 71.9 % complete.
# 71.97 % complete.
# 72.04 % complete.
# 72.11 % complete.
# 72.18 % complete.
# 72.25 % complete.
# 72.32 % complete.
# 72.39 % complete.
# 72.46 % complete.
# 72.54 % complete.
# 72.61 % complete.
# 72.68 % complete.
# 72.75 % complete.
# 72.82 % complete.
# 72.89 % complete.
# 72.96 % complete.
# 73.03 % complete.
# 73.1 % complete.
# 73.17 % complete.
# 73.24 % complete.
# 73.32 % complete.
# 73.39 % complete.
# 73.46 % complete.
# 73.53 % complete.
# 73.6 % complete.
# 73.67 % complete.
# 73.74 % complete.
# 73.81 % complete.
# 73.88 % complete.
# 73.95 % complete.
# 74.02 % complete.
# 74.1 % complete.
# 74.17 % complete.
# 74.24 % complete.
# 74.31 % complete.
# 74.38 % complete.
# 74.45 % complete.
# 74.52 % complete.
# 74.59 % complete.
# 74.66 % complete.
# 74.73 % complete.
# 74.8 % complete.
# 74.88 % complete.
# 74.95 % complete.
# 75.02 % complete.
# 75.09 % complete.
# 75.16 % complete.
# 75.23 % complete.
# 75.3 % complete.
# 75.37 % complete.
# 75.44 % complete.
# 75.51 % complete.
# 75.59 % complete.
# 75.66 % complete.
# 75.73 % complete.
# 75.8 % complete.
# 75.87 % complete.
# 75.94 % complete.
# 76.01 % complete.
# 76.08 % complete.
# 76.15 % complete.
# 76.22 % complete.
# 76.29 % complete.
# 76.37 % complete.
# 76.44 % complete.
# 76.51 % complete.
# 76.58 % complete.
# 76.65 % complete.
# 76.72 % complete.
# 76.79 % complete.
# 76.86 % complete.
# 76.93 % complete.
# 77.0 % complete.
# 77.07 % complete.
# 77.15 % complete.
# 77.22 % complete.
# 77.29 % complete.
# 77.36 % complete.
# 77.43 % complete.
# 77.5 % complete.
# 77.57 % complete.
# 77.64 % complete.
# 77.71 % complete.
# 77.78 % complete.
# 77.85 % complete.
# 77.93 % complete.
# 78.0 % complete.
# 78.07 % complete.
# 78.14 % complete.
# 78.21 % complete.
# 78.28 % complete.
# 78.35 % complete.
# 78.42 % complete.
# 78.49 % complete.
# 78.56 % complete.
# 78.63 % complete.
# 78.71 % complete.
# 78.78 % complete.
# 78.85 % complete.
# 78.92 % complete.
# 78.99 % complete.
# 79.06 % complete.
# 79.13 % complete.
# 79.2 % complete.
# 79.27 % complete.
# 79.34 % complete.
# 79.41 % complete.
# 79.49 % complete.
# 79.56 % complete.
# 79.63 % complete.
# 79.7 % complete.
# 79.77 % complete.
# 79.84 % complete.
# 79.91 % complete.
# 79.98 % complete.
# 80.05 % complete.
# 80.12 % complete.
# 80.2 % complete.
# 80.27 % complete.
# 80.34 % complete.
# 80.41 % complete.
# 80.48 % complete.
# 80.55 % complete.
# 80.62 % complete.
# 80.69 % complete.
# 80.76 % complete.
# 80.83 % complete.
# 80.9 % complete.
# 80.98 % complete.
# 81.05 % complete.
# 81.12 % complete.
# 81.19 % complete.
# 81.26 % complete.
# 81.33 % complete.
# 81.4 % complete.
# 81.47 % complete.
# 81.54 % complete.
# 81.61 % complete.
# 81.68 % complete.
# 81.76 % complete.
# 81.83 % complete.
# 81.9 % complete.
# 81.97 % complete.
# 82.04 % complete.
# 82.11 % complete.
# 82.18 % complete.
# 82.25 % complete.
# 82.32 % complete.
# 82.39 % complete.
# 82.46 % complete.
# 82.54 % complete.
# 82.61 % complete.
# 82.68 % complete.
# 82.75 % complete.
# 82.82 % complete.
# 82.89 % complete.
# 82.96 % complete.
# 83.03 % complete.
# 83.1 % complete.
# 83.17 % complete.
# 83.24 % complete.
# 83.32 % complete.
# 83.39 % complete.
# 83.46 % complete.
# 83.53 % complete.
# 83.6 % complete.
# 83.67 % complete.
# 83.74 % complete.
# 83.81 % complete.
# 83.88 % complete.
# 83.95 % complete.
# 84.02 % complete.
# 84.1 % complete.
# 84.17 % complete.
# 84.24 % complete.
# 84.31 % complete.
# 84.38 % complete.
# 84.45 % complete.
# 84.52 % complete.
# 84.59 % complete.
# 84.66 % complete.
# 84.73 % complete.
# 84.8 % complete.
# 84.88 % complete.
# 84.95 % complete.
# 85.02 % complete.
# 85.09 % complete.
# 85.16 % complete.
# 85.23 % complete.
# 85.3 % complete.
# 85.37 % complete.
# 85.44 % complete.
# 85.51 % complete.
# 85.59 % complete.
# 85.66 % complete.
# 85.73 % complete.
# 85.8 % complete.
# 85.87 % complete.
# 85.94 % complete.
# 86.01 % complete.
# 86.08 % complete.
# 86.15 % complete.
# 86.22 % complete.
# 86.29 % complete.
# 86.37 % complete.
# 86.44 % complete.
# 86.51 % complete.
# 86.58 % complete.
# 86.65 % complete.
# 86.72 % complete.
# 86.79 % complete.
# 86.86 % complete.
# 86.93 % complete.
# 87.0 % complete.
# 87.07 % complete.
# 87.15 % complete.
# 87.22 % complete.
# 87.29 % complete.
# 87.36 % complete.
# 87.43 % complete.
# 87.5 % complete.
# 87.57 % complete.
# 87.64 % complete.
# 87.71 % complete.
# 87.78 % complete.
# 87.85 % complete.
# 87.93 % complete.
# 88.0 % complete.
# 88.07 % complete.
# 88.14 % complete.
# 88.21 % complete.
# 88.28 % complete.
# 88.35 % complete.
# 88.42 % complete.
# 88.49 % complete.
# 88.56 % complete.
# 88.63 % complete.
# 88.71 % complete.
# 88.78 % complete.
# 88.85 % complete.
# 88.92 % complete.
# 88.99 % complete.
# 89.06 % complete.
# 89.13 % complete.
# 89.2 % complete.
# 89.27 % complete.
# 89.34 % complete.
# 89.41 % complete.
# 89.49 % complete.
# 89.56 % complete.
# 89.63 % complete.
# 89.7 % complete.
# 89.77 % complete.
# 89.84 % complete.
# 89.91 % complete.
# 89.98 % complete.
# 90.05 % complete.
# 90.12 % complete.
# 90.2 % complete.
# 90.27 % complete.
# 90.34 % complete.
# 90.41 % complete.
# 90.48 % complete.
# 90.55 % complete.
# 90.62 % complete.
# 90.69 % complete.
# 90.76 % complete.
# 90.83 % complete.
# 90.9 % complete.
# 90.98 % complete.
# 91.05 % complete.
# 91.12 % complete.
# 91.19 % complete.
# 91.26 % complete.
# 91.33 % complete.
# 91.4 % complete.
# 91.47 % complete.
# 91.54 % complete.
# 91.61 % complete.
# 91.68 % complete.
# 91.76 % complete.
# 91.83 % complete.
# 91.9 % complete.
# 91.97 % complete.
# 92.04 % complete.
# 92.11 % complete.
# 92.18 % complete.
# 92.25 % complete.
# 92.32 % complete.
# 92.39 % complete.
# 92.46 % complete.
# 92.54 % complete.
# 92.61 % complete.
# 92.68 % complete.
# 92.75 % complete.
# 92.82 % complete.
# 92.89 % complete.
# 92.96 % complete.
# 93.03 % complete.
# 93.1 % complete.
# 93.17 % complete.
# 93.24 % complete.
# 93.32 % complete.
# 93.39 % complete.
# 93.46 % complete.
# 93.53 % complete.
# 93.6 % complete.
# 93.67 % complete.
# 93.74 % complete.
# 93.81 % complete.
# 93.88 % complete.
# 93.95 % complete.
# 94.02 % complete.
# 94.1 % complete.
# 94.17 % complete.
# 94.24 % complete.
# 94.31 % complete.
# 94.38 % complete.
# 94.45 % complete.
# 94.52 % complete.
# 94.59 % complete.
# 94.66 % complete.
# 94.73 % complete.
# 94.8 % complete.
# 94.88 % complete.
# 94.95 % complete.
# 95.02 % complete.
# 95.09 % complete.
# 95.16 % complete.
# 95.23 % complete.
# 95.3 % complete.
# 95.37 % complete.
# 95.44 % complete.
# 95.51 % complete.
# 95.59 % complete.
# 95.66 % complete.
# 95.73 % complete.
# 95.8 % complete.
# 95.87 % complete.
# 95.94 % complete.
# 96.01 % complete.
# 96.08 % complete.
# 96.15 % complete.
# 96.22 % complete.
# 96.29 % complete.
# 96.37 % complete.
# 96.44 % complete.
# 96.51 % complete.
# 96.58 % complete.
# 96.65 % complete.
# 96.72 % complete.
# 96.79 % complete.
# 96.86 % complete.
# 96.93 % complete.
# 97.0 % complete.
# 97.07 % complete.
# 97.15 % complete.
# 97.22 % complete.
# 97.29 % complete.
# 97.36 % complete.
# 97.43 % complete.
# 97.5 % complete.
# 97.57 % complete.
# 97.64 % complete.
# 97.71 % complete.
# 97.78 % complete.
# 97.85 % complete.
# 97.93 % complete.
# 98.0 % complete.
# 98.07 % complete.
# 98.14 % complete.
# 98.21 % complete.
# 98.28 % complete.
# 98.35 % complete.
# 98.42 % complete.
# 98.49 % complete.
# 98.56 % complete.
# 98.63 % complete.
# 98.71 % complete.
# 98.78 % complete.
# 98.85 % complete.
# 98.92 % complete.
# 98.99 % complete.
# 99.06 % complete.
# 99.13 % complete.
# 99.2 % complete.
# 99.27 % complete.
# 99.34 % complete.
# 99.41 % complete.
# 99.49 % complete.
# 99.56 % complete.
# 99.63 % complete.
# 99.7 % complete.
# 99.77 % complete.
# 99.84 % complete.
# 99.91 % complete.
# 99.98 % complete.
# Total time taken for training of all the three algorithms
# --- 133.36698484420776 seconds ---

# %% [markdown]
# Once the training is done, one can analyse the trained Q values using all the three algorithms and verify its accuracy/optimality in terms of available state transition graphs.

# %%
# Generate heat-maps for analysis
crms=np.transpose(Q_target_QLRF)

np.random.seed(24)
df_dummy = pd.DataFrame({'Q': np.linspace(0, 3, 4)})
df_dummy = pd.concat([df_dummy, pd.DataFrame(crms)],axis=1)

import seaborn as sns

cm = sns.light_palette("blue", as_cmap=True)

s5 = df_dummy.style.background_gradient(cmap=cm)
s5
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <style  type="text/css" >
#     #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col6 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col8 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col9 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col10 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col12 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col14 {
#             background-color:  #4f4fff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col15 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col16 {
#             background-color:  #a2a2ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col17 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col18 {
#             background-color:  #8181ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col19 {
#             background-color:  #a6a6ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col20 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col21 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col22 {
#             background-color:  #dfdfff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col23 {
#             background-color:  #c3c3ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col24 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col25 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col26 {
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col27 {
#             background-color:  #dfdfff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col28 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col29 {
#             background-color:  #7070ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col30 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col31 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col32 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col33 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col34 {
#             background-color:  #b3b3ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col35 {
#             background-color:  #4d4dff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col36 {
#             background-color:  #c0c0ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col37 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col38 {
#             background-color:  #aaaaff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col39 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col40 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col41 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col42 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col43 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col44 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col45 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col46 {
#             background-color:  #a2a2ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col47 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col48 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col49 {
#             background-color:  #6363ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col50 {
#             background-color:  #b7b7ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col51 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col52 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col53 {
#             background-color:  #7b7bff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col54 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col55 {
#             background-color:  #c3c3ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col56 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col57 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col58 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_9d436872_ce43_11ea_b7a8_0242ac1c0002row0_col59 {
#             background

# %%
# Formatting the plots for better visualisation

t = np.linspace(0, 1, len(scores_QLRF))

plt.rcParams.update({'font.family': 'Times New Roman', 'font.size': 20, 'font.weight': 'bold'})
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 2
fig = plt.figure(figsize=(12, 9))

plt.plot(t, scores_QLRF, label=r'$QLRF$', color = 'green', marker='s')

plt.xlabel('Normalized Epochs',fontsize='20', fontweight='bold')
plt.ylabel('Normalized Error',fontsize='20', fontweight='bold')
plt.legend(prop={"size":26})
plt.grid(alpha=0.3)
plt.show()

# np.save('scores_QLRF.npy',scores_QLRF)

# fig.savefig('MDP_plot.png', dpi=300, bbox_inches = "tight")
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # **Step 3: Lyapunoc analysis and Self-Triggered Control**
#
# In this section, we provide Lyapunov analysis of Q table calculated using above code and implement self-triggered control fo either of the one algorithms (particularly QLRF).

# %%
# please make a note that all conventions used for this analysis are completely reverse of the ones used in the training module.
# For instance 111-7 for training and 111-0 in the analysis followed under.
import numpy as np
import cvxpy as cp

# Please note: In this example, we make use of model-based approach.

# Generate tabular TPM for LMI analysis
probs_U1=np.zeros([np.power(2,ns),np.power(2,ns)])
probs_U2=np.zeros([np.power(2,ns),np.power(2,ns)])
probs_U3=np.zeros([np.power(2,ns),np.power(2,ns)])
probs_U4=np.zeros([np.power(2,ns),np.power(2,ns)])
for i in range(len(points_list_U1)):
  probs_U1[int(points_list_U1[i][0])][int(points_list_U1[i][1])]=edge_weights_U1[points_list_U1[i]]
  probs_U2[int(points_list_U2[i][0])][int(points_list_U2[i][1])]=edge_weights_U2[points_list_U2[i]]
  probs_U3[int(points_list_U3[i][0])][int(points_list_U3[i][1])]=edge_weights_U3[points_list_U3[i]]
  probs_U4[int(points_list_U4[i][0])][int(points_list_U4[i][1])]=edge_weights_U4[points_list_U4[i]]

PTM=np.stack((probs_U1,probs_U2,probs_U3,probs_U4))

goal=511-507                              # desired attractor: 000000100-507
del_2n=np.identity(np.power(2,ns))        # del_{2n}=[del^{i}_{2n}]
del_t_2n=np.delete(del_2n,goal,axis=1)    # del^{t}_{2n}=[del_{2n}\del^{goal}_{2n}]
del_2n_2n=del_2n[:,goal]                  # del^{goal}_{2n}

# generating inverted probability transition matrices
dim_p=PTM[0].shape[0]
F=np.zeros([dim_p,dim_p])
F1=np.zeros([dim_p,dim_p])
F2=np.zeros([dim_p,dim_p])
F3=np.zeros([dim_p,dim_p])
F4=np.zeros([dim_p,dim_p])
for i in range(dim_p):
  for j in range(dim_p):
    F4[i,j]=PTM[0][dim_p-1-j,dim_p-1-i]
    F3[i,j]=PTM[1][dim_p-1-j,dim_p-1-i]
    F2[i,j]=PTM[2][dim_p-1-j,dim_p-1-i]
    F1[i,j]=PTM[3][dim_p-1-j,dim_p-1-i]

# \phi_{2^{2n}}=diag[del^{i}_{2n}]
dim_phi=np.power(2,2*ns)
phi_test=np.zeros([dim_phi,dim_p])
for i in range(dim_p):
  phi_test[i*dim_p:(i+1)*dim_p,i]=del_2n[:,i]

# generating reversed QLRF table values
q_dummy=Q_target_QLRF.T
q_buff=np.zeros([np.power(2,nc),np.power(2,ns)])
for i in range(q_dummy.shape[0]):
  for j in range(q_dummy.shape[1]):
    q_buff[i,j]=q_dummy[q_dummy.shape[0]-1-i,q_dummy.shape[1]-1-j]

uqlrf=np.zeros([np.power(2,nc),np.power(2,ns)])
for i in range(np.power(2,ns)):
  # idx=np.argmax(q_buff[:,i])
  idx=np.squeeze(np.where(q_buff[:,i]==np.max(q_buff[:,i])))
  if idx.size>1:
    idx=int(np.random.choice(idx,size=1))
  uqlrf[idx,i]=1

# concatenated TPM and action matrices
p=np.concatenate([F1,F2,F3,F4],axis=1)
u=uqlrf

# \tilde_{P}=Pu\phi
piP=np.zeros([dim_p,dim_phi])
piP=(np.kron(p,np.identity(1))).dot(np.kron(u,np.identity(dim_p)))
piP=piP.dot(phi_test)

# We solve the LMI defined in manuscript considering the closed loop \tilde{P} and solving for a LP problem \lambda.T*s given constraints.
# kindly refer to the detailed description of the constraints in the manuscript.
lambda_i = cp.Variable([np.power(2,ns),1])
gam = cp.Variable()
obj = cp.Minimize(gam)

LMI1 = cp.bmat([
                 [lambda_i.T*del_2n_2n]
])
cons1=LMI1 <= 0
cons6=LMI1 >= 0

LMI2 = cp.bmat([
                 [lambda_i.T*piP.dot(del_2n_2n)]
])
cons2=LMI2 <= 0
cons7=LMI2 >= 0

LMI3 = cp.bmat([
                 [lambda_i.T*del_t_2n]
])

cons3 = LMI3 >= gam

LMI4 = cp.bmat([
                 [lambda_i.T*piP.dot(del_t_2n)-lambda_i.T*del_t_2n]
])

cons4 = LMI4 <= -gam
cons5 = gam >= 0.0
consf=[cons1,cons2,cons3,cons4,cons5,cons6,cons7]
prob = cp.Problem(obj,consf)

prob.solve()
print("value of lambda is \n",lambda_i.value)
# Out:
# value of lambda is
#  [[9.14091239e-02]
#  [1.30518849e-01]
#  [1.11381887e-01]
#  [1.32552941e-01]
#  [1.27368309e-15]
#  [8.77475837e-02]
#  [8.46324690e-02]
#  [1.05420280e-01]
#  [1.12847049e-01]
#  [1.30499750e-01]
#  [1.12847049e-01]
#  [1.22580455e-01]
#  [8.53616064e-02]
#  [1.21317626e-01]
#  [8.53616064e-02]
#  [1.09744495e-01]
#  [8.70349946e-02]
#  [9.93603858e-02]
#  [1.08879714e-01]
#  [1.04376650e-01]
#  [7.52510750e-02]
#  [9.35095165e-02]
#  [1.04021453e-01]
#  [1.04300469e-01]
#  [1.08879714e-01]
#  [1.52334272e-01]
#  [1.29836598e-01]
#  [1.04376650e-01]
#  [1.04021453e-01]
#  [1.04300469e-01]
#  [1.53367836e-01]
#  [1.90309661e-01]
#  [8.24158984e-02]
#  [1.23252894e-01]
#  [1.32862251e-01]
#  [1.44057917e-01]
#  [1.73649075e-03]
#  [1.01710762e-01]
#  [1.49312662e-01]
#  [1.88423900e-01]
#  [1.12847049e-01]
#  [1.30499750e-01]
#  [1.33214423e-01]
#  [1.43689597e-01]
#  [8.53616064e-02]
#  [1.21317626e-01]
#  [1.41794751e-01]
#  [1.55605270e-01]
#  [9.95504604e-02]
#  [1.04284681e-01]
#  [8.09579030e-02]
#  [6.60788748e-02]
#  [3.31028068e-02]
#  [1.37703773e-01]
#  [1.47867309e-01]
#  [1.02985296e-01]
#  [1.29836598e-01]
#  [1.04284681e-01]
#  [1.40768434e-01]
#  [1.04001129e-01]
#  [1.04021453e-01]
#  [1.58166026e-01]
#  [1.46152375e-01]
#  [1.48076088e-01]
#  [1.11381887e-01]
#  [1.23766602e-01]
#  [1.11381887e-01]
#  [1.53052081e-01]
#  [1.11381887e-01]
#  [1.32552941e-01]
#  [1.11381887e-01]
#  [1.32552941e-01]
#  [1.12847049e-01]
#  [1.30499750e-01]
#  [1.12847049e-01]
#  [1.30499750e-01]
#  [1.12847049e-01]
#  [1.14756528e-01]
#  [1.12847049e-01]
#  [1.14756528e-01]
#  [1.03648646e-01]
#  [1.40586184e-01]
#  [1.03648646e-01]
#  [1.04376650e-01]
#  [1.29836598e-01]
#  [1.04376650e-01]
#  [1.29836598e-01]
#  [1.04376650e-01]
#  [1.08879714e-01]
#  [1.52334272e-01]
#  [1.08879714e-01]
#  [1.04376650e-01]
#  [1.08879714e-01]
#  [1.52334272e-01]
#  [1.08879714e-01]
#  [1.04376650e-01]
#  [1.11381887e-01]
#  [1.24805200e-01]
#  [1.32862251e-01]
#  [1.44057917e-01]
#  [1.09939433e-01]
#  [1.11445399e-01]
#  [1.32862251e-01]
#  [1.40481019e-01]
#  [1.12847049e-01]
#  [1.14756528e-01]
#  [1.33214423e-01]
#  [1.48374054e-01]
#  [1.12847049e-01]
#  [1.30499750e-01]
#  [1.33214423e-01]
#  [1.48374054e-01]
#  [9.69303368e-02]
#  [8.53153080e-02]
#  [1.40768434e-01]
#  [8.98054657e-02]
#  [3.26268220e-02]
#  [3.33884577e-02]
#  [1.27659678e-01]
#  [1.01597357e-01]
#  [1.29836598e-01]
#  [1.04284681e-01]
#  [1.34141758e-01]
#  [1.10105136e-01]
#  [1.08879714e-01]
#  [1.04284681e-01]
#  [1.27659678e-01]
#  [1.04001129e-01]
#  [1.43082293e-01]
#  [1.53052081e-01]
#  [1.43082293e-01]
#  [1.29758198e-01]
#  [1.18031633e-01]
#  [1.30116316e-01]
#  [1.18031633e-01]
#  [1.30116316e-01]
#  [9.07545096e-02]
#  [1.06071129e-01]
#  [1.03747632e-01]
#  [1.22580455e-01]
#  [3.07351667e-02]
#  [1.07445959e-01]
#  [1.20891385e-01]
#  [1.21317626e-01]
#  [1.00023487e-01]
#  [1.04376650e-01]
#  [1.00023487e-01]
#  [1.04376650e-01]
#  [1.04087791e-01]
#  [1.04300469e-01]
#  [1.04087791e-01]
#  [1.04300469e-01]
#  [8.31438495e-02]
#  [1.47783046e-01]
#  [1.00023487e-01]
#  [1.19267671e-01]
#  [8.32382191e-02]
#  [9.98355000e-02]
#  [1.04087791e-01]
#  [1.04300469e-01]
#  [1.43082293e-01]
#  [1.29758198e-01]
#  [1.36861573e-01]
#  [1.40481019e-01]
#  [1.18031633e-01]
#  [1.30116316e-01]
#  [1.46584894e-01]
#  [1.53547176e-01]
#  [8.55368192e-02]
#  [1.13118622e-01]
#  [1.20463876e-01]
#  [1.33717257e-01]
#  [2.39361022e-02]
#  [1.16540490e-01]
#  [1.52045346e-01]
#  [1.54092040e-01]
#  [1.29836598e-01]
#  [1.04284681e-01]
#  [1.15244605e-01]
#  [1.04001129e-01]
#  [1.04087791e-01]
#  [1.58166026e-01]
#  [1.56521273e-01]
#  [1.48076088e-01]
#  [2.70596070e-02]
#  [9.32053234e-02]
#  [1.15244605e-01]
#  [3.32359732e-02]
#  [3.31286009e-02]
#  [1.16455934e-01]
#  [1.56521273e-01]
#  [8.47732124e-02]
#  [1.43082293e-01]
#  [1.53052081e-01]
#  [1.40731965e-01]
#  [1.53052081e-01]
#  [1.43082293e-01]
#  [1.29758198e-01]
#  [1.43082293e-01]
#  [1.29758198e-01]
#  [1.03747632e-01]
#  [1.14756528e-01]
#  [1.03747632e-01]
#  [1.14756528e-01]
#  [1.01742048e-01]
#  [9.30801241e-02]
#  [1.16087541e-01]
#  [1.14756528e-01]
#  [1.00023487e-01]
#  [1.04376650e-01]
#  [1.00023487e-01]
#  [1.19267671e-01]
#  [1.00023487e-01]
#  [1.04376650e-01]
#  [1.00023487e-01]
#  [1.04376650e-01]
#  [1.00023487e-01]
#  [1.04376650e-01]
#  [1.00023487e-01]
#  [1.52334272e-01]
#  [9.54357896e-02]
#  [6.59141889e-02]
#  [1.00023487e-01]
#  [1.52334272e-01]
#  [1.43082293e-01]
#  [1.29758198e-01]
#  [1.36861573e-01]
#  [1.40481019e-01]
#  [1.43082293e-01]
#  [1.53052081e-01]
#  [1.36861573e-01]
#  [1.40481019e-01]
#  [1.03747632e-01]
#  [1.09704464e-01]
#  [1.20463876e-01]
#  [1.33717257e-01]
#  [1.16087541e-01]
#  [8.70891223e-02]
#  [1.20463876e-01]
#  [1.43689597e-01]
#  [1.29836598e-01]
#  [1.04284681e-01]
#  [1.15244605e-01]
#  [1.04001129e-01]
#  [1.00023487e-01]
#  [1.04284681e-01]
#  [1.15244605e-01]
#  [1.04001129e-01]
#  [9.33139533e-02]
#  [8.56442336e-02]
#  [1.15244605e-01]
#  [4.60697580e-02]
#  [8.79479638e-02]
#  [6.97456560e-02]
#  [1.15244605e-01]
#  [5.36662555e-02]
#  [7.13927599e-02]
#  [1.05654953e-01]
#  [1.10857331e-01]
#  [1.17040288e-01]
#  [4.32462220e-02]
#  [1.12661795e-01]
#  [1.02655705e-01]
#  [1.34941234e-01]
#  [1.04700719e-01]
#  [1.02149777e-01]
#  [1.04700719e-01]
#  [1.02149777e-01]
#  [9.80702236e-02]
#  [1.24337526e-01]
#  [9.80702236e-02]
#  [1.35794314e-01]
#  [7.86826705e-02]
#  [1.28152569e-01]
#  [1.02853054e-01]
#  [1.28152569e-01]
#  [1.00776719e-01]
#  [1.13677194e-01]
#  [1.37402196e-01]
#  [1.31684665e-01]
#  [1.02853054e-01]
#  [1.02017995e-01]
#  [1.18230594e-01]
#  [1.02017995e-01]
#  [1.37402196e-01]
#  [1.71552271e-01]
#  [1.37402196e-01]
#  [1.31684665e-01]
#  [7.17574304e-02]
#  [1.17759700e-01]
#  [7.28509339e-02]
#  [1.03598346e-01]
#  [4.53465686e-02]
#  [1.03340076e-01]
#  [1.48672632e-01]
#  [1.53911900e-01]
#  [1.04700719e-01]
#  [1.28303721e-01]
#  [1.21634863e-01]
#  [1.03494954e-01]
#  [9.80702236e-02]
#  [1.35794314e-01]
#  [1.44267406e-01]
#  [1.50394871e-01]
#  [4.87060664e-02]
#  [8.95069764e-02]
#  [8.37541747e-02]
#  [3.31835353e-02]
#  [2.68605600e-02]
#  [9.43868665e-02]
#  [1.28780673e-01]
#  [5.84769227e-02]
#  [1.04561431e-01]
#  [1.04242274e-01]
#  [1.04161708e-01]
#  [1.03836679e-01]
#  [1.42834197e-01]
#  [1.18813230e-01]
#  [1.46847231e-01]
#  [1.13127371e-01]
#  [1.10857331e-01]
#  [1.01622922e-01]
#  [1.10857331e-01]
#  [1.52222452e-01]
#  [1.08937255e-01]
#  [1.02381304e-01]
#  [1.10857331e-01]
#  [1.31301911e-01]
#  [1.04700719e-01]
#  [1.28303721e-01]
#  [1.04700719e-01]
#  [1.02149777e-01]
#  [1.04700719e-01]
#  [1.28303721e-01]
#  [1.04700719e-01]
#  [1.02149777e-01]
#  [1.02853054e-01]
#  [7.18723274e-02]
#  [1.02853054e-01]
#  [1.02017995e-01]
#  [9.83986672e-02]
#  [5.25252580e-02]
#  [1.18230594e-01]
#  [1.02017995e-01]
#  [1.02853054e-01]
#  [1.02017995e-01]
#  [1.02853054e-01]
#  [1.02017995e-01]
#  [1.18230594e-01]
#  [1.02017995e-01]
#  [1.02853054e-01]
#  [1.23736204e-01]
#  [1.10857331e-01]
#  [1.08148243e-01]
#  [1.19266192e-01]
#  [1.37514088e-01]
#  [1.03978030e-01]
#  [8.19768076e-02]
#  [1.19266192e-01]
#  [1.40077813e-01]
#  [1.04700719e-01]
#  [1.02149777e-01]
#  [1.21634863e-01]
#  [1.32346497e-01]
#  [1.04700719e-01]
#  [1.02149777e-01]
#  [1.21634863e-01]
#  [1.32346497e-01]
#  [9.11548372e-02]
#  [7.49072105e-02]
#  [1.16181573e-01]
#  [4.19388755e-02]
#  [3.13379549e-02]
#  [3.33697214e-02]
#  [1.04161708e-01]
#  [3.33519749e-02]
#  [1.02853054e-01]
#  [1.04242274e-01]
#  [1.30973204e-01]
#  [1.03836679e-01]
#  [1.04561431e-01]
#  [1.04242274e-01]
#  [1.16181573e-01]
#  [1.03836679e-01]
#  [1.23176407e-01]
#  [1.52222452e-01]
#  [1.23176407e-01]
#  [1.17040288e-01]
#  [1.42513743e-01]
#  [1.34941234e-01]
#  [1.29506024e-01]
#  [1.40731804e-01]
#  [5.42108025e-02]
#  [1.12028890e-01]
#  [1.07422605e-01]
#  [1.02149777e-01]
#  [4.25696957e-02]
#  [1.09716396e-01]
#  [1.02293546e-01]
#  [1.35794314e-01]
#  [1.04127537e-01]
#  [1.02017995e-01]
#  [1.04127537e-01]
#  [1.02017995e-01]
#  [1.04131317e-01]
#  [1.31684665e-01]
#  [1.04131317e-01]
#  [1.31684665e-01]
#  [8.63532414e-02]
#  [1.02017995e-01]
#  [1.04127537e-01]
#  [1.02017995e-01]
#  [6.62811353e-02]
#  [1.64020152e-01]
#  [1.04131317e-01]
#  [1.71552271e-01]
#  [1.23176407e-01]
#  [1.17040288e-01]
#  [1.37033930e-01]
#  [1.40077813e-01]
#  [1.29506024e-01]
#  [1.34941234e-01]
#  [1.44157461e-01]
#  [1.61335795e-01]
#  [5.72423194e-02]
#  [9.15114116e-02]
#  [3.32448234e-02]
#  [3.27986470e-02]
#  [3.39757104e-02]
#  [1.13675090e-01]
#  [1.12020895e-01]
#  [1.28574757e-01]
#  [1.04127537e-01]
#  [1.04275482e-01]
#  [1.04162725e-01]
#  [1.04214488e-01]
#  [1.42834197e-01]
#  [1.18813230e-01]
#  [9.99498717e-02]
#  [1.13127371e-01]
#  [3.32280965e-02]
#  [9.35477962e-02]
#  [3.32592139e-02]
#  [3.33054698e-02]
#  [3.31549357e-02]
#  [6.55304211e-02]
#  [2.72305336e-02]
#  [3.32936528e-02]
#  [1.23203777e-01]
#  [1.17040288e-01]
#  [1.23203777e-01]
#  [1.17040288e-01]
#  [1.23176407e-01]
#  [1.17040288e-01]
#  [1.23176407e-01]
#  [1.17040288e-01]
#  [1.02251356e-01]
#  [6.96970612e-02]
#  [1.04332770e-01]
#  [1.02149777e-01]
#  [8.26070328e-02]
#  [7.38563002e-02]
#  [1.04332770e-01]
#  [1.02149777e-01]
#  [1.02853054e-01]
#  [1.02017995e-01]
#  [1.04127537e-01]
#  [1.02017995e-01]
#  [1.02853054e-01]
#  [1.02017995e-01]
#  [1.04127537e-01]
#  [1.02017995e-01]
#  [9.81287328e-02]
#  [8.49060147e-02]
#  [1.04127537e-01]
#  [1.02017995e-01]
#  [6.70316127e-02]
#  [4.11967600e-02]
#  [1.04127537e-01]
#  [1.28152569e-01]
#  [1.23203777e-01]
#  [1.17040288e-01]
#  [1.37033930e-01]
#  [1.40077813e-01]
#  [1.23176407e-01]
#  [1.17040288e-01]
#  [1.46368191e-01]
#  [1.40077813e-01]
#  [3.44365835e-02]
#  [3.03672580e-02]
#  [1.03712173e-01]
#  [1.03494954e-01]
#  [8.84387244e-02]
#  [3.05947095e-02]
#  [1.03712173e-01]
#  [1.03494954e-01]
#  [1.04127537e-01]
#  [1.04242274e-01]
#  [1.04162725e-01]
#  [1.04214488e-01]
#  [1.04127537e-01]
#  [1.01715930e-01]
#  [1.04162725e-01]
#  [1.04214488e-01]
#  [3.36742802e-02]
#  [3.35442111e-02]
#  [1.04162725e-01]
#  [3.33164001e-02]
#  [3.34021852e-02]
#  [2.97538878e-02]
#  [1.04162725e-01]
#  [3.34006433e-02]]

# %% [markdown]
# Next, we use the \lambda calculated from LMI above to design self-triggered control schedule

# %%
rev_s=np.power(2,ns)-1
rev_a=np.power(2,nc)-1
goal=rev_s-507
dummy_states=4

# matrices used to stored steps-actions log at every step
steps_log=[]
act_log=[]
steps_log_buff=[]
act_log_buff=[]

# \lambda calculated from LMIs
lm=lambda_i.value

# Initialising lambda values for current state and next state
lm_cs=0
lm_ns=0
# TPM matrices for the current problem
PTM=np.stack((probs_U1,probs_U2,probs_U3,probs_U4))

for k in range(np.power(2,ns)):
  for j in range(np.power(2,nc)):
    # define all states-action pairs to understand respective transitions and schedules
    current_state=k
    action=rev_a-j
    # flush the logs after every succesful computation
    steps_log_buff=[]
    act_log_buff=[]
    # create two dummy step-action pair for visualisation
    steps_log_buff.append(current_state)
    act_log_buff.append(action)
    steps_log_buff.append(current_state)
    act_log_buff.append(action)

    # Run until current state reaches desired attractor
    while (rev_s-int(current_state))!=goal:
      # Allow the control to traverse along negative gradient of the constituent \lambda values.
      # calculate possible transitions from TPM and check for minimum \lambda and transit accordingly as per Algorithm 2.
      nz_trans=PTM[int(action)][int(current_state),:].nonzero()[0]
      idxc=np.squeeze(np.where(lm[rev_s-nz_trans]==np.min(lm[rev_s-nz_trans])))
      if idxc.size>1:
        idxc=int(np.random.choice(idxc,size=1))
      next_state = nz_trans[idxc]

      # Compare current state \lambda with next state in terms of Lyapunov condition violations or self-loops or reaching the desired attractor
      if lm[rev_s-int(current_state)]<lm[rev_s-int(next_state)] or (current_state==next_state and (rev_s-current_state)!=goal) :
        action_buff=rev_a-np.squeeze(np.where(uqlrf[:,int(rev_s-current_state)]==np.max(uqlrf[:,int(rev_s-current_state)])))           # re-compute actions as per QLRF control
        if action_buff.size > 1:
              action = int(np.random.choice(action_buff, size = 1))
        else:
              action = int(action_buff)
      else:
        # maintain a log of steps taken and control actions employed
        steps_log_buff.append(next_state)
        current_state=next_state
        act_log_buff.append(action)
    
    # Run for some dummy states even when the desired attractor is reached in order to assure infinite time stabilisation.
    for i in range(dummy_states):
      nz_trans=PTM[int(action)][int(current_state),:].nonzero()[0]
      idxc=np.squeeze(np.where(lm[rev_s-nz_trans]==np.min(lm[rev_s-nz_trans])))
      if idxc.size>1:
        idxc=int(np.random.choice(idxc,size=1))
      next_state = nz_trans[idxc]

      if lm[rev_s-int(current_state)]<lm[rev_s-int(next_state)] or (current_state==next_state and (rev_s-int(current_state))!=goal) :
        action_buff=rev_a-np.squeeze(np.where(uqlrf[:,int(rev_s-current_state)]==np.max(uqlrf[:,int(rev_s-current_state)])))           # re-compute actions as per QLRF control
        if action_buff.size > 1:
              action = int(np.random.choice(action_buff, size = 1))
        else:
              action = int(action_buff)
      else:
        steps_log_buff.append(next_state)
        current_state=next_state
        act_log_buff.append(action)

    # Store the step-action log at the end of every evaluation  
    steps_log.append(steps_log_buff)
    act_log.append(act_log_buff)

  # Print percentage of completion at every step
  print(np.round(k/512*100,2),'%complete')
# Out:
# 0.0 %complete
# 0.2 %complete
# 0.39 %complete
# 0.59 %complete
# 0.78 %complete
# 0.98 %complete
# 1.17 %complete
# 1.37 %complete
# 1.56 %complete
# 1.76 %complete
# 1.95 %complete
# 2.15 %complete
# 2.34 %complete
# 2.54 %complete
# 2.73 %complete
# 2.93 %complete
# 3.12 %complete
# 3.32 %complete
# 3.52 %complete
# 3.71 %complete
# 3.91 %complete
# 4.1 %complete
# 4.3 %complete
# 4.49 %complete
# 4.69 %complete
# 4.88 %complete
# 5.08 %complete
# 5.27 %complete
# 5.47 %complete
# 5.66 %complete
# 5.86 %complete
# 6.05 %complete
# 6.25 %complete
# 6.45 %complete
# 6.64 %complete
# 6.84 %complete
# 7.03 %complete
# 7.23 %complete
# 7.42 %complete
# 7.62 %complete
# 7.81 %complete
# 8.01 %complete
# 8.2 %complete
# 8.4 %complete
# 8.59 %complete
# 8.79 %complete
# 8.98 %complete
# 9.18 %complete
# 9.38 %complete
# 9.57 %complete
# 9.77 %complete
# 9.96 %complete
# 10.16 %complete
# 10.35 %complete
# 10.55 %complete
# 10.74 %complete
# 10.94 %complete
# 11.13 %complete
# 11.33 %complete
# 11.52 %complete
# 11.72 %complete
# 11.91 %complete
# 12.11 %complete
# 12.3 %complete
# 12.5 %complete
# 12.7 %complete
# 12.89 %complete
# 13.09 %complete
# 13.28 %complete
# 13.48 %complete
# 13.67 %complete
# 13.87 %complete
# 14.06 %complete
# 14.26 %complete
# 14.45 %complete
# 14.65 %complete
# 14.84 %complete
# 15.04 %complete
# 15.23 %complete
# 15.43 %complete
# 15.62 %complete
# 15.82 %complete
# 16.02 %complete
# 16.21 %complete
# 16.41 %complete
# 16.6 %complete
# 16.8 %complete
# 16.99 %complete
# 17.19 %complete
# 17.38 %complete
# 17.58 %complete
# 17.77 %complete
# 17.97 %complete
# 18.16 %complete
# 18.36 %complete
# 18.55 %complete
# 18.75 %complete
# 18.95 %complete
# 19.14 %complete
# 19.34 %complete
# 19.53 %complete
# 19.73 %complete
# 19.92 %complete
# 20.12 %complete
# 20.31 %complete
# 20.51 %complete
# 20.7 %complete
# 20.9 %complete
# 21.09 %complete
# 21.29 %complete
# 21.48 %complete
# 21.68 %complete
# 21.88 %complete
# 22.07 %complete
# 22.27 %complete
# 22.46 %complete
# 22.66 %complete
# 22.85 %complete
# 23.05 %complete
# 23.24 %complete
# 23.44 %complete
# 23.63 %complete
# 23.83 %complete
# 24.02 %complete
# 24.22 %complete
# 24.41 %complete
# 24.61 %complete
# 24.8 %complete
# 25.0 %complete
# 25.2 %complete
# 25.39 %complete
# 25.59 %complete
# 25.78 %complete
# 25.98 %complete
# 26.17 %complete
# 26.37 %complete
# 26.56 %complete
# 26.76 %complete
# 26.95 %complete
# 27.15 %complete
# 27.34 %complete
# 27.54 %complete
# 27.73 %complete
# 27.93 %complete
# 28.12 %complete
# 28.32 %complete
# 28.52 %complete
# 28.71 %complete
# 28.91 %complete
# 29.1 %complete
# 29.3 %complete
# 29.49 %complete
# 29.69 %complete
# 29.88 %complete
# 30.08 %complete
# 30.27 %complete
# 30.47 %complete
# 30.66 %complete
# 30.86 %complete
# 31.05 %complete
# 31.25 %complete
# 31.45 %complete
# 31.64 %complete
# 31.84 %complete
# 32.03 %complete
# 32.23 %complete
# 32.42 %complete
# 32.62 %complete
# 32.81 %complete
# 33.01 %complete
# 33.2 %complete
# 33.4 %complete
# 33.59 %complete
# 33.79 %complete
# 33.98 %complete
# 34.18 %complete
# 34.38 %complete
# 34.57 %complete
# 34.77 %complete
# 34.96 %complete
# 35.16 %complete
# 35.35 %complete
# 35.55 %complete
# 35.74 %complete
# 35.94 %complete
# 36.13 %complete
# 36.33 %complete
# 36.52 %complete
# 36.72 %complete
# 36.91 %complete
# 37.11 %complete
# 37.3 %complete
# 37.5 %complete
# 37.7 %complete
# 37.89 %complete
# 38.09 %complete
# 38.28 %complete
# 38.48 %complete
# 38.67 %complete
# 38.87 %complete
# 39.06 %complete
# 39.26 %complete
# 39.45 %complete
# 39.65 %complete
# 39.84 %complete
# 40.04 %complete
# 40.23 %complete
# 40.43 %complete
# 40.62 %complete
# 40.82 %complete
# 41.02 %complete
# 41.21 %complete
# 41.41 %complete
# 41.6 %complete
# 41.8 %complete
# 41.99 %complete
# 42.19 %complete
# 42.38 %complete
# 42.58 %complete
# 42.77 %complete
# 42.97 %complete
# 43.16 %complete
# 43.36 %complete
# 43.55 %complete
# 43.75 %complete
# 43.95 %complete
# 44.14 %complete
# 44.34 %complete
# 44.53 %complete
# 44.73 %complete
# 44.92 %complete
# 45.12 %complete
# 45.31 %complete
# 45.51 %complete
# 45.7 %complete
# 45.9 %complete
# 46.09 %complete
# 46.29 %complete
# 46.48 %complete
# 46.68 %complete
# 46.88 %complete
# 47.07 %complete
# 47.27 %complete
# 47.46 %complete
# 47.66 %complete
# 47.85 %complete
# 48.05 %complete
# 48.24 %complete
# 48.44 %complete
# 48.63 %complete
# 48.83 %complete
# 49.02 %complete
# 49.22 %complete
# 49.41 %complete
# 49.61 %complete
# 49.8 %complete
# 50.0 %complete
# 50.2 %complete
# 50.39 %complete
# 50.59 %complete
# 50.78 %complete
# 50.98 %complete
# 51.17 %complete
# 51.37 %complete
# 51.56 %complete
# 51.76 %complete
# 51.95 %complete
# 52.15 %complete
# 52.34 %complete
# 52.54 %complete
# 52.73 %complete
# 52.93 %complete
# 53.12 %complete
# 53.32 %complete
# 53.52 %complete
# 53.71 %complete
# 53.91 %complete
# 54.1 %complete
# 54.3 %complete
# 54.49 %complete
# 54.69 %complete
# 54.88 %complete
# 55.08 %complete
# 55.27 %complete
# 55.47 %complete
# 55.66 %complete
# 55.86 %complete
# 56.05 %complete
# 56.25 %complete
# 56.45 %complete
# 56.64 %complete
# 56.84 %complete
# 57.03 %complete
# 57.23 %complete
# 57.42 %complete
# 57.62 %complete
# 57.81 %complete
# 58.01 %complete
# 58.2 %complete
# 58.4 %complete
# 58.59 %complete
# 58.79 %complete
# 58.98 %complete
# 59.18 %complete
# 59.38 %complete
# 59.57 %complete
# 59.77 %complete
# 59.96 %complete
# 60.16 %complete
# 60.35 %complete
# 60.55 %complete
# 60.74 %complete
# 60.94 %complete
# 61.13 %complete
# 61.33 %complete
# 61.52 %complete
# 61.72 %complete
# 61.91 %complete
# 62.11 %complete
# 62.3 %complete
# 62.5 %complete
# 62.7 %complete
# 62.89 %complete
# 63.09 %complete
# 63.28 %complete
# 63.48 %complete
# 63.67 %complete
# 63.87 %complete
# 64.06 %complete
# 64.26 %complete
# 64.45 %complete
# 64.65 %complete
# 64.84 %complete
# 65.04 %complete
# 65.23 %complete
# 65.43 %complete
# 65.62 %complete
# 65.82 %complete
# 66.02 %complete
# 66.21 %complete
# 66.41 %complete
# 66.6 %complete
# 66.8 %complete
# 66.99 %complete
# 67.19 %complete
# 67.38 %complete
# 67.58 %complete
# 67.77 %complete
# 67.97 %complete
# 68.16 %complete
# 68.36 %complete
# 68.55 %complete
# 68.75 %complete
# 68.95 %complete
# 69.14 %complete
# 69.34 %complete
# 69.53 %complete
# 69.73 %complete
# 69.92 %complete
# 70.12 %complete
# 70.31 %complete
# 70.51 %complete
# 70.7 %complete
# 70.9 %complete
# 71.09 %complete
# 71.29 %complete
# 71.48 %complete
# 71.68 %complete
# 71.88 %complete
# 72.07 %complete
# 72.27 %complete
# 72.46 %complete
# 72.66 %complete
# 72.85 %complete
# 73.05 %complete
# 73.24 %complete
# 73.44 %complete
# 73.63 %complete
# 73.83 %complete
# 74.02 %complete
# 74.22 %complete
# 74.41 %complete
# 74.61 %complete
# 74.8 %complete
# 75.0 %complete
# 75.2 %complete
# 75.39 %complete
# 75.59 %complete
# 75.78 %complete
# 75.98 %complete
# 76.17 %complete
# 76.37 %complete
# 76.56 %complete
# 76.76 %complete
# 76.95 %complete
# 77.15 %complete
# 77.34 %complete
# 77.54 %complete
# 77.73 %complete
# 77.93 %complete
# 78.12 %complete
# 78.32 %complete
# 78.52 %complete
# 78.71 %complete
# 78.91 %complete
# 79.1 %complete
# 79.3 %complete
# 79.49 %complete
# 79.69 %complete
# 79.88 %complete
# 80.08 %complete
# 80.27 %complete
# 80.47 %complete
# 80.66 %complete
# 80.86 %complete
# 81.05 %complete
# 81.25 %complete
# 81.45 %complete
# 81.64 %complete
# 81.84 %complete
# 82.03 %complete
# 82.23 %complete
# 82.42 %complete
# 82.62 %complete
# 82.81 %complete
# 83.01 %complete
# 83.2 %complete
# 83.4 %complete
# 83.59 %complete
# 83.79 %complete
# 83.98 %complete
# 84.18 %complete
# 84.38 %complete
# 84.57 %complete
# 84.77 %complete
# 84.96 %complete
# 85.16 %complete
# 85.35 %complete
# 85.55 %complete
# 85.74 %complete
# 85.94 %complete
# 86.13 %complete
# 86.33 %complete
# 86.52 %complete
# 86.72 %complete
# 86.91 %complete
# 87.11 %complete
# 87.3 %complete
# 87.5 %complete
# 87.7 %complete
# 87.89 %complete
# 88.09 %complete
# 88.28 %complete
# 88.48 %complete
# 88.67 %complete
# 88.87 %complete
# 89.06 %complete
# 89.26 %complete
# 89.45 %complete
# 89.65 %complete
# 89.84 %complete
# 90.04 %complete
# 90.23 %complete
# 90.43 %complete
# 90.62 %complete
# 90.82 %complete
# 91.02 %complete
# 91.21 %complete
# 91.41 %complete
# 91.6 %complete
# 91.8 %complete
# 91.99 %complete
# 92.19 %complete
# 92.38 %complete
# 92.58 %complete
# 92.77 %complete
# 92.97 %complete
# 93.16 %complete
# 93.36 %complete
# 93.55 %complete
# 93.75 %complete
# 93.95 %complete
# 94.14 %complete
# 94.34 %complete
# 94.53 %complete
# 94.73 %complete
# 94.92 %complete
# 95.12 %complete
# 95.31 %complete
# 95.51 %complete
# 95.7 %complete
# 95.9 %complete
# 96.09 %complete
# 96.29 %complete
# 96.48 %complete
# 96.68 %complete
# 96.88 %complete
# 97.07 %complete
# 97.27 %complete
# 97.46 %complete
# 97.66 %complete
# 97.85 %complete
# 98.05 %complete
# 98.24 %complete
# 98.44 %complete
# 98.63 %complete
# 98.83 %complete
# 99.02 %complete
# 99.22 %complete
# 99.41 %complete
# 99.61 %complete
# 99.8 %complete

# %% [markdown]
# Next, using the steps computed from previous analysis, we plot the steps taken and triggering times for better understanding.

# %%
# Visualization of STC scheme as per steps computed from previous analysis

from matplotlib.ticker import StrMethodFormatter
fig, ax = plt.subplots(1,1,figsize=(12,9))
plt.rcParams.update({'font.family': 'Times New Roman', 'font.size': 20, 'font.weight': 'bold'})
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 2

# number of steps to be shown
nsteps=20

# create a dummy desired line showing goal values
desired_line=[]
goal=507            # Kindly make a note here 111111011-507, since none of the system parameters comprising reversed values are used for this part.
for i in range(nsteps):
  desired_line.append(goal)

# Kindly note, that here we make use of differen markers so as to better visualise overlapping triggering times, compared to same marker in the manuscript. Although, the reader has priviliges to download and make changes accordingly.
mrkrs=list([".","o","v","^","<",">","8","s","p","P","*","h","H","X","D","d"])

# Predefine random points to be visualised and reverse it as per standard conventions used in this part of work
c=np.array([7,111,203,395,444,511])[::-1]
labels=[]

# plot till all the points required are shown
for i in range(len(c)):
  # plot all the 4th values of steps showing steps computed for initial action u=11.
  t=range(len(steps_log[4*c[i]][:nsteps]))

  # This part here checks for bit changes in successive values of actions so as to understand triggering taken by the STC scheme.
  dummy=np.array(act_log[4*c[i]])
  dummy_ind=np.where(dummy[:-1] != dummy[1:])[0]

  ax.yaxis.set_ticks(np.arange(0, np.power(2,ns), 70))
  ax.step(t,np.array(steps_log[4*c[i]][:nsteps]),linewidth=3, linestyle='dashed', marker=np.random.choice(mrkrs), markersize=15, markevery = [np.concatenate([[0],dummy_ind],axis=0)], label=r'$s_{i}$'.format(i={int(512-c[i])}))
  ax.yaxis.set_major_formatter(StrMethodFormatter("{x:09b}"))
  ax.set_ylabel('States', fontsize='20', fontweight='bold')
  ax.set_xlabel('Steps', fontsize='20', fontweight='bold')

# plot desired line on top for better understanding.
t=range(nsteps)
ax.step(t,desired_line, linewidth=3, linestyle='dashed', alpha=0.7, marker='o', markersize=5, label=r'$s_{e}$')
ax.legend(prop={"size":26})
ax.grid(alpha=0.3)

np.save('steps_log.npy',steps_log)
np.save('act_log.npy',act_log)
np.save('desired_line.npy',desired_line)

# save the figure for future references
# fig.savefig('9node_steps2.png',dpi=300, bbox_inches = "tight")
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py:191: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return Path(verts[markevery], _slice_or_none(codes, markevery))

# %%
last=[]
for i in range(len(steps_log)):
  last.append(steps_log[i][-1])

np.unique(last)
# Out:
# array([507])
